# %%
import loudoun_wildlife_conservancy as l
import test as t
import re
import datetime
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
soup = i.bs4_page('https://loudounwildlife.org/events/')

# %%
soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="en-US">
# <!-- START head -->
# <head>
# <meta charset="utf-8"/>
# <meta content="" name="theme-color"/>
# <meta content="SJn6rEwUmBAySJ9cxU8S2tNCFvgdNFEDblLuOQMmt9M" name="google-site-verification">
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport">
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://loudounwildlife.org/xmlrpc.php" rel="pingback"/>
# <!--[if lte IE 8]>
# 	<script src="https://loudounwildlife.org/wp-content/themes/HighendWP/scripts/html5shiv.js" type="text/javascript"></script>
# 	<![endif]-->
# <title>Events Archive - Loudoun Wildlife Conservancy</title>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, user-scalable=no" name="viewport">
# <!-- This site is optimized with the Yoast SEO plugin v12.8 - https://yoast.com/wordpress/plugins/seo/ -->
# ...

# %%
scripts = soup.find_all('script', {'type':'application/ld+json'})[1:]

# %%
scripts
# Out:
# [<script type="application/ld+json">
# ...

# %%
events = []

# %%
event_list = json.loads(scripts[0].string[2:])

# %%
url = event_list[0]['url']

# %%
url
# Out:
# 'https://loudounwildlife.org/event/adventures-with-raptors/'

# %%
soup2 = i.bs4_page(url)

# %%
soup2
# Out:
# <!DOCTYPE HTML>
#
# <html lang="en-US">
# <!-- START head -->
# <head>
# <meta charset="utf-8"/>
# <meta content="" name="theme-color"/>
# <meta content="SJn6rEwUmBAySJ9cxU8S2tNCFvgdNFEDblLuOQMmt9M" name="google-site-verification">
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport">
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://loudounwildlife.org/xmlrpc.php" rel="pingback"/>
# <!--[if lte IE 8]>
# 	<script src="https://loudounwildlife.org/wp-content/themes/HighendWP/scripts/html5shiv.js" type="text/javascript"></script>
# 	<![endif]-->
# <title>Adventures with Raptors - Loudoun Wildlife Conservancy</title>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, user-scalable=no" name="viewport">
# <!-- This site is optimized with the Yoast SEO plugin v12.8 - https://yoast.com/wordpress/plugins/seo/ -->
# ...

# %%
script2 = soup2.find('div', {'class':"tribe-events-single-event-description tribe-events-content"})

# %%
script2.text
# Out:
# '\nJoin wildlife rehabilitator and educator with Secret Garden Birds and Bees, Liz Dennison and Belinda Burwell of Wildlife Veterinary Care in Boyce for an informative Loudoun Wildlife Conservancy program about raptors and their place in our natural world. The program will be followed by an opportunity for everyone to personally visit, interact with and take photos with their ambassador birds. All are welcome. \nQuestions: Contact info@loudounwildlife.org.\n\n\nShare via:\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMore\n\n\n\n\n\n\n\n'

# %%
script2
# Out:
# []

# %%
type(script2.text)
# Out:
# str

# %%
scripts = soup.find_all('script', {'type':'application/ld+json'})[1:]
events = []
for tag in scripts:
    event_list = json.loads(tag.string[2:])
    for event in event_list:
        event_dict = {}
        event_dict['Event Name'] = event['name']
        event_dict['Event Description'] = event['description']
        event_dict['Event Start Date'] = event['startDate'][:10]
        event_dict['Event Start Time'] = event['startDate'][11:19]
        event_dict['Event End Date'] = event['endDate'][:10]
        event_dict['Event End Time'] = event['endDate'][11:19]
        event_dict['All Day Event'] = False
        event_dict['Timezone'] = 'America/New_York'
        event_dict['Event Venue Name'] = event['location']['name']
        event_dict['Event Organizers'] = 'Loudoun Wildlife Conservancy'
        event_dict['Event Cost'] = 0
        event_dict['Event Currency Symbol'] = '$'
        event_dict['Event Category'] = ''
        event_dict['Event Website'] = event['url']
        event_dict['Event Featured Image'] = event['image']
        events.append(event_dict)

# %%
events
# Out:
# [{'Event Name': 'Adventures with Raptors',
#   'Event Description': 'Join wildlife rehabilitator and educator with Secret Garden Birds and Bees, Liz Dennison and Belinda Burwell of Wildlife Veterinary Care in Boyce for an informative Loudoun Wildlife Conservancy program about raptors and their place in our natural world. The program will be followed by an opportunity for everyone to personally visit, interact with and take photos with their ambassador birds. All are welcome. Questions: Contact info@loudounwildlife.org.',
#   'Event Start Date': '2020-01-19',
#   'Event Start Time': '14:00:00',
#   'Event End Date': '2020-01-19',
#   'Event End Time': '14:00:00',
#   'All Day Event': False,
#   'Timezone': 'America/New_York',
#   'Event Venue Name': 'Brambleton Library',
#   'Event Organizers': 'Loudoun Wildlife Conservancy',
#   'Event Cost': 0,
#   'Event Currency Symbol': '$',
#   'Event Category': '',
# ...

# %%
events = l.main()

# %%
events
# Out:
# [{'Event Name': 'Adventures with Raptors',
#   'Event Description': 'Join wildlife rehabilitator and educator with Secret Garden Birds and Bees, Liz Dennison and Belinda Burwell of Wildlife Veterinary Care in Boyce for an informative Loudoun Wildlife Conservancy program about raptors and their place in our natural world. The program will be followed by an opportunity for everyone to personally visit, interact with and take photos with their ambassador birds. All are welcome. Questions: Contact info@loudounwildlife.org.',
#   'Event Start Date': '2020-01-19',
#   'Event Start Time': '14:00:00',
#   'Event End Date': '2020-01-19',
#   'Event End Time': '14:00:00',
#   'All Day Event': False,
#   'Timezone': 'America/New_York',
#   'Event Venue Name': 'Brambleton Library',
#   'Event Organizers': 'Loudoun Wildlife Conservancy',
#   'Event Cost': [],
#   'Event Currency Symbol': '$',
#   'Event Category': '',
# ...

# %%
words = events[7]['Event Description']

# %%
words
# Out:
# 'If the weather cooperates, birds of prey numbers increase dramatically in the county in the winter as our resident birds are joined by many others. Join Loudoun Wildlife Conservancy for a class by raptor expert Liam McGranaghan on identifying birds of prey in the morning. After a break for lunch, the group will reconvene for a winter raptor search as we drive the back roads of Loudoun with frequent stops to find and identify the many hawks, an owl or two, and any other birds who winter here. The field trip will last until dusk. Space is limited for this popular event so please register early. All participants will be sent details on the class and field trip after registration. Fee: $10/members; $25/non-members. Registration required. Questions: Contact info@loudounwildlife.org.Sorry, registration for this event is full.'

# %%
if 'Fee:' in words:
    if re.findall(r"\$[0-9][0-9]", words) > 1:
        re.findall(r"\$[0-9][0-9]/", words)
re.findall(r"\$[0-9][0-9]", words)
# Out:
# ['$10', '$25']

# %%
re.findall(r"[-+]?\d*\.\d+|\d+", words)
# Out:
# ['10', '25']
