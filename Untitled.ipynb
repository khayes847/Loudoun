# %%
from datetime import datetime
import sys
import requests
from bs4 import BeautifulSoup
import logging
import re
import math
# %load_ext autoreload
# %autoreload 2

# %%
r = requests.get('https://loudounwildlife.org/events/')
content = r.content
soup = BeautifulSoup(content, 'html.parser')

# %%
soup.find_all()
# Out:
# <!DOCTYPE HTML>
#
# <html lang="en-US">
# <!-- START head -->
# <head>
# <meta charset="utf-8"/>
# <meta content="" name="theme-color"/>
# <meta content="SJn6rEwUmBAySJ9cxU8S2tNCFvgdNFEDblLuOQMmt9M" name="google-site-verification">
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport">
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://loudounwildlife.org/xmlrpc.php" rel="pingback"/>
# <!--[if lte IE 8]>
# 	<script src="https://loudounwildlife.org/wp-content/themes/HighendWP/scripts/html5shiv.js" type="text/javascript"></script>
# 	<![endif]-->
# <title>Events Archive - Loudoun Wildlife Conservancy</title>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, user-scalable=no" name="viewport">
# <!-- This site is optimized with the Yoast SEO plugin v12.7.1 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
# <link href="https://loudounwildlife.org/events/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="object" property="og:type"/>
# <meta content="Events Archive - Loudoun Wildlife Conservancy" property="og:title"/>
# <meta content="https://loudounwildlife.org/events/" property="og:url"/>
# <meta content="Loudoun Wildlife Conservancy" property="og:site_name"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="Events Archive - Loudoun Wildlife Conservancy" name="twitter:title"/>
# <script class="yoast-schema-graph yoast-schema-graph--main" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://loudounwildlife.org/#website","url":"https://loudounwildlife.org/","name":"Loudoun Wildlife Conservancy","description":"People and Wildlife Living in Harmony","potentialAction":{"@type":"SearchAction","target":"https://loudounwildlife.org/?s={search_term_string}","query-input":"required name=search_term_string"}},{"@type":"CollectionPage","@id":"https://loudounwildlife.org/events/#webpage","url":"https://loudounwildlife.org/events/","inLanguage":"en-US","name":"Events Archive - Loudoun Wildlife Conservancy","isPartOf":{"@id":"https://loudounwildlife.org/#website"}}]}</script>
# <!-- / Yoast SEO plugin. -->
# <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
# <link href="//www.google.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://loudounwildlife.org/feed/" rel="alternate" title="Loudoun Wildlife Conservancy » Feed" type="application/rss+xml"/>
# <link href="https://loudounwildlife.org/comments/feed/" rel="alternate" title="Loudoun Wildlife Conservancy » Comments Feed" type="application/rss+xml"/>
# <link href="https://loudounwildlife.org/events/?ical=1" rel="alternate" title="Loudoun Wildlife Conservancy » iCal Feed" type="text/calendar"/>
# <link href="https://loudounwildlife.org/events/feed/" rel="alternate" title="Loudoun Wildlife Conservancy » Events Feed" type="application/rss+xml"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/common/src/resources/css/accessibility.min.css?ver=4.10.2" id="tribe-accessibility-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/src/resources/css/tribe-events-full.min.css?ver=4.9.13" id="tribe-events-full-calendar-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/events-calendar-pro/src/resources/css/tribe-events-pro-full.min.css?ver=4.7.10" id="tribe-events-full-pro-calendar-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/vendor/jquery/smoothness/jquery-ui-1.8.23.custom.css?ver=4.9.13" id="tribe-events-custom-jquery-styles-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/vendor/bootstrap-datepicker/css/bootstrap-datepicker.standalone.min.css?ver=4.9.13" id="tribe-events-bootstrap-datepicker-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/src/resources/css/tribe-events-theme.min.css?ver=4.9.13" id="tribe-events-calendar-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/src/resources/css/tribe-events-full-mobile.min.css?ver=4.9.13" id="tribe-events-calendar-full-mobile-style-css" media="only screen and (max-width: 768px)" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/src/resources/css/tribe-events-theme-mobile.min.css?ver=4.9.13" id="tribe-events-calendar-mobile-style-css" media="only screen and (max-width: 768px)" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/events-calendar-pro/src/resources/css/tribe-events-pro-theme.min.css?ver=4.7.10" id="tribe-events-calendar-pro-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/events-calendar-pro/src/resources/css/tribe-events-pro-theme-mobile.min.css?ver=4.7.10" id="tribe-events-calendar-pro-mobile-style-css" media="only screen and (max-width: 768px)" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/events-calendar-pro/src/resources/css/tribe-events-pro-full-mobile.min.css?ver=4.7.10" id="tribe-events-calendar-full-pro-mobile-style-css" media="only screen and (max-width: 768px)" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/common/src/resources/css/common-skeleton.min.css?ver=4.10.2" id="tribe-common-skeleton-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/common/src/resources/css/tooltip.min.css?ver=4.10.2" id="tribe-tooltip-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/contact-form-7/includes/css/styles.css?ver=5.1.6" id="contact-form-7-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/essential-grid/public/assets/css/settings.css?ver=2.3.2" id="essential-grid-plugin-settings-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans%3A300%2C400%2C600%2C700%2C800&amp;ver=5.3" id="tp-open-sans-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Raleway%3A100%2C200%2C300%2C400%2C500%2C600%2C700%2C800%2C900&amp;ver=5.3" id="tp-raleway-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Droid+Serif%3A400%2C700&amp;ver=5.3" id="tp-droid-serif-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/essential-grid/public/assets/font/fontello/css/fontello.css?ver=2.3.2" id="tp-fontello-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/revslider/public/assets/css/settings.css?ver=5.4.8.3" id="rs-plugin-settings-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="rs-plugin-settings-inline-css" type="text/css">
# #rs-demo-id {}
# </style>
# <link href="https://loudounwildlife.org/wp-content/plugins/socialsnap/assets/css/socialsnap.css?ver=1.1.7" id="socialsnap-styles-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/themes/HighendWP/style.css?ver=5.3" id="highend-parent-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/themes/HighendWP-child/style.css?ver=5.3" id="highend-child-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/themes/HighendWP/style.css?ver=3.6.2" id="highend-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/themes/HighendWP/assets/css/responsive.css?ver=3.6.2" id="highend_responsive-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/themes/HighendWP/assets/css/icons.css?ver=3.6.2" id="highend_icomoon-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/uploads/highend/dynamic-styles.css?ver=1572543499" id="highend_dynamic_styles-css" media="all" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 9]>
# <link rel='stylesheet' id='vc_lte_ie9-css'  href='https://loudounwildlife.org/wp-content/plugins/js_composer/assets/css/vc_lte_ie9.min.css?ver=6.0.5' type='text/css' media='screen' />
# <![endif]-->
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1/jquery.min.js?ver=5.3" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/vendor/bootstrap-datepicker/js/bootstrap-datepicker.min.js?ver=4.9.13" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/vendor/jquery-resize/jquery.ba-resize.min.js?ver=4.9.13" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/vendor/jquery-placeholder/jquery.placeholder.min.js?ver=4.9.13" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/common/vendor/momentjs/moment.min.js?ver=4.10.2" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var tribe_js_config = {"permalink_settings":"\/%year%\/%monthnum%\/%postname%\/","events_post_type":"tribe_events","events_base":"https:\/\/loudounwildlife.org\/events\/","update_urls":{"shortcode":{"list":true,"month":true,"day":true}},"debug":""};
# var tribe_js_config = {"permalink_settings":"\/%year%\/%monthnum%\/%postname%\/","events_post_type":"tribe_events","events_base":"https:\/\/loudounwildlife.org\/events\/","update_urls":{"shortcode":{"list":true,"month":true,"day":true}},"debug":""};
# /* ]]> */
# </script>
# <script src="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/src/resources/js/tribe-events.min.js?ver=4.9.13" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var TribeEventsPro = {"geocenter":{"max_lat":39.293705000000003,"max_lng":-77.154268000000002,"min_lat":37.431573,"min_lng":-78.656893999999994},"map_tooltip_event":"Event: ","map_tooltip_address":"Address: "};
# var TribeEventsPro = {"geocenter":{"max_lat":39.293705000000003,"max_lng":-77.154268000000002,"min_lat":37.431573,"min_lng":-78.656893999999994},"map_tooltip_event":"Event: ","map_tooltip_address":"Address: "};
# /* ]]> */
# </script>
# <script src="https://loudounwildlife.org/wp-content/plugins/events-calendar-pro/src/resources/js/tribe-events-pro.min.js?ver=4.7.10" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/vendor/php-date-formatter/js/php-date-formatter.min.js?ver=4.9.13" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var tribe_dynamic_help_text = {"date_with_year":"F j, Y","date_no_year":"F j","datepicker_format":"Y-m-d","datepicker_format_index":"0","days":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"daysShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"months":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthsShort":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"msgs":"[\"This event is from %%starttime%% to %%endtime%% on %%startdatewithyear%%.\",\"This event is at %%starttime%% on %%startdatewithyear%%.\",\"This event is all day on %%startdatewithyear%%.\",\"This event starts at %%starttime%% on %%startdatenoyear%% and ends at %%endtime%% on %%enddatewithyear%%\",\"This event starts at %%starttime%% on %%startdatenoyear%% and ends on %%enddatewithyear%%\",\"This event is all day starting on %%startdatenoyear%% and ending on %%enddatewithyear%%.\"]"};
# /* ]]> */
# </script>
# <script src="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/src/resources/js/events-dynamic.min.js?ver=4.9.13" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/src/resources/js/tribe-events-bar.min.js?ver=4.9.13" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-content/plugins/essential-grid/public/assets/js/jquery.esgbox.min.js?ver=2.3.2" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var wpimagelazyload_settings = {"wpimagelazyloadsetting_skipiframe":"false","wpimagelazyloadsetting_skipparent":"","wpimagelazyloadsetting_skipallparent":"","wpimagelazyloadsetting_skipvideo":"false","wpimagelazyloadsetting_loadonposition":"0","wpimagelazyloadsetting_importantvc":"1"};
# /* ]]> */
# </script>
# <script src="https://loudounwildlife.org/wp-content/plugins/wp-image-lazy-load/image_lazy_load.js?ver=1" type="text/javascript"></script>
# <link href="https://loudounwildlife.org/wp-json/" rel="https://api.w.org/"/>
# <link href="https://loudounwildlife.org/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://loudounwildlife.org/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <style type="text/css">
# 		iframe{
# 			max-width: 100%;
# 		}
# 	</style> <script type="text/javascript">
# 			var ajaxRevslider;
#
# 			jQuery(document).ready(function() {
# 				// CUSTOM AJAX CONTENT LOADING FUNCTION
# 				ajaxRevslider = function(obj) {
#
# 					// obj.type : Post Type
# 					// obj.id : ID of Content to Load
# 					// obj.aspectratio : The Aspect Ratio of the Container / Media
# 					// obj.selector : The Container Selector where the Content of Ajax will be injected. It is done via the Essential Grid on Return of Content
#
# 					var content = "";
#
# 					data = {};
#
# 					data.action = 'revslider_ajax_call_front';
# 					data.client_action = 'get_slider_html';
# 					data.token = 'be24001dfc';
# 					data.type = obj.type;
# 					data.id = obj.id;
# 					data.aspectratio = obj.aspectratio;
#
# 					// SYNC AJAX REQUEST
# 					jQuery.ajax({
# 						type:"post",
# 						url:"https://loudounwildlife.org/wp-admin/admin-ajax.php",
# 						dataType: 'json',
# 						data:data,
# 						async:false,
# 						success: function(ret, textStatus, XMLHttpRequest) {
# 							if(ret.success == true)
# 								content = ret.data;
# 						},
# 						error: function(e) {
# 							console.log(e);
# 						}
# 					});
#
# 					 // FIRST RETURN THE CONTENT WHEN IT IS LOADED !!
# 					 return content;
# 				};
#
# 				// CUSTOM AJAX FUNCTION TO REMOVE THE SLIDER
# 				var ajaxRemoveRevslider = function(obj) {
# 					return jQuery(obj.selector+" .rev_slider").revkill();
# 				};
#
# 				// EXTEND THE AJAX CONTENT LOADING TYPES WITH TYPE AND FUNCTION
# 				var extendessential = setInterval(function() {
# 					if (jQuery.fn.tpessential != undefined) {
# 						clearInterval(extendessential);
# 						if(typeof(jQuery.fn.tpessential.defaults) !== 'undefined') {
# 							jQuery.fn.tpessential.defaults.ajaxTypes.push({type:"revslider",func:ajaxRevslider,killfunc:ajaxRemoveRevslider,openAnimationSpeed:0.3});
# 							// type:  Name of the Post to load via Ajax into the Essential Grid Ajax Container
# 							// func: the Function Name which is Called once the Item with the Post Type has been clicked
# 							// killfunc: function to kill in case the Ajax Window going to be removed (before Remove function !
# 							// openAnimationSpeed: how quick the Ajax Content window should be animated (default is 0.3)
# 						}
# 					}
# 				},30);
# 			});
# 		</script>
# <meta content="v1" name="tec-api-version"/><meta content="https://loudounwildlife.org" name="tec-api-origin"/><link href="https://loudounwildlife.org/wp-json/tribe/events/v1/" rel="https://theeventscalendar.com/"/><meta content="#dd9933" name="theme-color"/> <style type="text/css">
# 			body, .team-position, .hb-single-next-prev .text-inside, .hb-dropdown-box.cart-dropdown .buttons a, input[type=text], textarea, input[type=email], input[type=password], input[type=tel], #fancy-search input[type=text], #fancy-search .ui-autocomplete li .search-title, .format-quote .quote-post-wrapper blockquote, table th, .hb-button, .woocommerce #payment #place_order, .woocommerce-page #payment #place_order, input[type=submit], a.read-more, blockquote.pullquote, blockquote, .hb-skill-meter .hb-skill-meter-title, .hb-tabs-wrapper .nav-tabs li a, #main-wrapper .coupon-code input.button,#main-wrapper .form-row input.button,#main-wrapper input.checkout-button,#main-wrapper input.hb-update-cart,.woocommerce-page #main-wrapper .shipping-calculator-form-hb button.button, .hb-accordion-pane, .hb-accordion-tab {
# 						font-family: "Open Sans", sans-serif;
# 						font-size: 16px;
# 						line-height: 22px;
# 						letter-spacing: 0px;
# 						font-weight: normal;
# 					}a.read-more, input[type=submit], .hb-caption-layer .hb-button, .hb-push-button-text, #pre-footer-area .hb-button, .hb-button, .hb-single-next-prev .text-inside, #main-wrapper .coupon-code input.button,#main-wrapper .form-row input.button,#main-wrapper input.checkout-button,#main-wrapper input.hb-update-cart,.woocommerce-page #main-wrapper .shipping-calculator-form-hb button.button { font-weight: 700; letter-spacing: 1px }#hb-side-menu li a, #main-nav ul.sub-menu li a, #main-nav ul.sub-menu ul li a, #main-nav, #main-nav li a, .light-menu-dropdown #main-nav > li.megamenu > ul.sub-menu > li > a, #main-nav > li.megamenu > ul.sub-menu > li > a {
# 						font-family: "Open Sans", sans-serif;
# 						font-size: 16px;
# 						letter-spacing: 0px;
# 						font-weight: normal;
# 						text-transform: none;
# 					}#main-nav ul.sub-menu li a, #hb-side-menu ul.sub-menu li a, #main-nav ul.sub-menu ul li a, ul.sub-menu .widget-item h4, #main-nav > li.megamenu > ul.sub-menu > li > a #main-nav > li.megamenu > ul.sub-menu > li > a, #main-nav > li.megamenu > ul.sub-menu > li > a {
# 						font-family: "Open Sans", sans-serif;
# 						font-size: 15px;
# 						letter-spacing: 0px;
# 						font-weight: ;
# 						text-transform: none;
# 					}#copyright-wrapper, #copyright-wrapper a {
# 						font-family: "Cabin Condensed", sans-serif;
# 						font-size: 14px;
# 						line-height: 22px;
# 						letter-spacing: 0px;
# 						font-weight: normal;
# 					}h1, article.single h1.title, #hb-page-title .light-text h1, #hb-page-title .dark-text h1 {
# 						font-family: "Open Sans", sans-serif;
# 						font-size: 26px;
# 						line-height: 28px;
# 						letter-spacing: 0px;
# 						font-weight: 700;
# 					}h2, #hb-page-title h2, .post-content h2.title {
# 						font-family: "Open Sans", sans-serif;
# 						font-size: 22px;
# 						line-height: 26px;
# 						letter-spacing: 0px;
# 						font-weight: 700;
# 					}h3, h3.title-class, .hb-callout-box h3, .hb-gal-standard-description h3 {
# 						font-family: "Open Sans", sans-serif;
# 						font-size: 20px;
# 						line-height: 24px;
# 						letter-spacing: 0px;
# 						font-weight: 700;
# 					}h4, .widget-item h4, #respond h3, .content-box h4, .feature-box h4.bold {
# 						font-family: "Open Sans", sans-serif;
# 						font-size: 18px;
# 						line-height: 22px;
# 						letter-spacing: 0px;
# 						font-weight: 700;
# 					}h5, #comments h5, #respond h5, .testimonial-author h5 {
# 						font-family: "Open Sans", sans-serif;
# 						font-size: 16px;
# 						line-height: 20px;
# 						letter-spacing: 0px;
# 						font-weight: 700;
# 					}			</style>
# <script type="text/javascript">var ajaxurl = "https://loudounwildlife.org/wp-admin/admin-ajax.php"</script><meta content="Powered by WPBakery Page Builder - drag and drop page builder for WordPress." name="generator">
# <meta content="noindex,follow" name="robots">
# <script type="application/ld+json">
# [{"@context":"http://schema.org","@type":"Event","name":"Giving Tuesday!","description":"&lt;p&gt;Love Loudoun, nature and the creatures that live here? Show your love by donating to Loudoun Wildlife Conservancy today \u2013 Giving Tuesday! \u00a0Help us help to preserve and protect the habitat that enhances the quality of life for you and all around us. Show your support today by clicking here! Thank you!&lt;/p&gt;\\n","image":"https://loudounwildlife.org/wp-content/uploads/2019/10/GivingTuesdayLarge-600.png","url":"https://loudounwildlife.org/event/giving-tuesday-2/","startDate":"2019-12-03T00:00:00-05:00","endDate":"2019-12-03T23:59:59-05:00","performer":"Organization"},{"@context":"http://schema.org","@type":"Event","name":"The Birds of Loudoun County","description":"&lt;p&gt;Loudoun County\u2019s extensive diversity of natural areas comprised of rich riparian buffers along the Potomac and its tributaries, large upland forests along the Blue Ridge and its other ridges, many farms and meadows, and its occasional park results in an abundant and diverse bird life. Using the extensive information gained from the Loudoun Wildlife Conservancy\u2019s [&hellip;]&lt;/p&gt;\\n","image":"https://loudounwildlife.org/wp-content/uploads/2019/03/Birds-of-Loudoun.jpg","url":"https://loudounwildlife.org/event/the-birds-of-loudoun-county-5/","startDate":"2019-12-12T19:00:00-05:00","endDate":"2019-12-12T19:00:00-05:00","location":{"@type":"Place","name":"Ashburn Library","description":"","url":"https://loudounwildlife.org/venue/ashburn-library/","address":{"@type":"PostalAddress","streetAddress":"43316 Hay Road","addressLocality":"Ashburn","addressRegion":"VA","postalCode":"20147","addressCountry":"United States"},"telephone":"","sameAs":"https://library.loudoun.gov/Our-Libraries/Ashburn-Library"},"performer":"Organization"},{"@context":"http://schema.org","@type":"Event","name":"Central Loudoun Christmas Bird Count","description":"&lt;p&gt;Join Loudoun Wildlife Conservancy as we participate in National Audubon Society\u2019s annual Christmas Bird Count. Begun in 1899, these surveys are held all over North America, with the results used to better understand bird populations and dynamics. Our count circle has a 15-mile diameter and covers 177 square miles of Loudoun\u2019s countryside: north to Waterford, [&hellip;]&lt;/p&gt;\\n","image":"https://loudounwildlife.org/wp-content/uploads/2019/10/Cedar-Waxwing-Gerco-Hoogeweg-300px.jpg","url":"https://loudounwildlife.org/event/central-loudoun-christmas-bird-count-3/","startDate":"2019-12-28T00:00:00-05:00","endDate":"2019-12-28T23:59:59-05:00","performer":"Organization"},{"@context":"http://schema.org","@type":"Event","name":"Loudoun Wildlife Open House and Wine Tasting","description":"&lt;p&gt;Stop by Loudoun Wildlife Conservancy\u2019s office for some wine, light snacks, and fellowship.\u00a0 We\u2019d love to get to know our members and hope you\u2019ll come and spend some time with President Julie Borneman, Executive Director Michael Myers, Board members, and other key volunteers. Come socialize and get a behind-the-scenes look at our operations. Questions: Contact [&hellip;]&lt;/p&gt;\\n","image":"https://loudounwildlife.org/wp-content/uploads/2018/10/Gatehouse.jpg","url":"https://loudounwildlife.org/event/loudoun-wildlife-open-house-and-wine-tasting/","startDate":"2019-12-07T11:00:00-05:00","endDate":"2019-12-07T16:00:00-05:00","location":{"@type":"Place","name":"The Gatehouse at Morven Park","description":"&lt;p&gt;Please note: There is no street parking permitted at 17638 Old Waterford Road. To reach the Gatehouse, enter Morven Park on Old Waterford Road, follow the road as far as the parking lot then turn right, then an immediate right again onto a gravel road. There is a sign that says Loudoun Wildlife Conservancy. Follow [&hellip;]&lt;/p&gt;\\n","url":"https://loudounwildlife.org/venue/the-gate-house-at-morven-park/","address":{"@type":"PostalAddress","streetAddress":"17638 Old Waterfor ...
# </script><meta content="Powered by Slider Revolution 5.4.8.3 - responsive, Mobile-Friendly Slider Plugin for WordPress with comfortable drag and drop interface." name="generator">
# <script type="text/javascript">function setREVStartSize(e){
# 						try{ e.c=jQuery(e.c);var i=jQuery(window).width(),t=9999,r=0,n=0,l=0,f=0,s=0,h=0;
# 							if(e.responsiveLevels&&(jQuery.each(e.responsiveLevels,function(e,f){f>i&&(t=r=f,l=e),i>f&&f>r&&(r=f,n=e)}),t>r&&(l=n)),f=e.gridheight[l]||e.gridheight[0]||e.gridheight,s=e.gridwidth[l]||e.gridwidth[0]||e.gridwidth,h=i/s,h=h>1?1:h,f=Math.round(h*f),"fullscreen"==e.sliderLayout){var u=(e.c.width(),jQuery(window).height());if(void 0!=e.fullScreenOffsetContainer){var c=e.fullScreenOffsetContainer.split(",");if (c) jQuery.each(c,function(e,i){u=jQuery(i).length>0?u-jQuery(i).outerHeight(!0):u}),e.fullScreenOffset.split("%").length>1&&void 0!=e.fullScreenOffset&&e.fullScreenOffset.length>0?u-=jQuery(window).height()*parseInt(e.fullScreenOffset,0)/100:void 0!=e.fullScreenOffset&&e.fullScreenOffset.length>0&&(u-=parseInt(e.fullScreenOffset,0))}f=u}else void 0!=e.minHeight&&f<e.minHeight&&(f=e.minHeight);e.c.closest(".rev_slider_wrapper").css({height:f})
# 						}catch(d){console.log("Failure at Presize of Slider:"+d)}
# 					};</script>
# <noscript><style> .wpb_animate_when_almost_visible { opacity: 1; }</style></noscript>
# <!-- Theme Options Font Settings -->
# <style type="text/css">
# 	body, .team-position, .hb-single-next-prev .text-inside, .hb-dropdown-box.cart-dropdown .buttons a, input[type=text], textarea, input[type=email], input[type=password], input[type=tel], #fancy-search input[type=text], #fancy-search .ui-autocomplete li .search-title, .quote-post-format .quote-post-wrapper blockquote, table th, .hb-button, .woocommerce #payment #place_order, .woocommerce-page #payment #place_order, input[type=submit], a.read-more, blockquote.pullquote, blockquote, .hb-skill-meter .hb-skill-meter-title, .hb-tabs-wrapper .nav-tabs li a, #main-wrapper .coupon-code input.button,#main-wrapper .form-row input.button,#main-wrapper input.checkout-button,#main-wrapper input.hb-update-cart,.woocommerce-page #main-wrapper .shipping-calculator-form-hb button.button, .hb-accordion-pane, .hb-accordion-tab {
# 				font-family: "Open Sans", sans-serif;
# 				font-size: 16px;
# 				line-height: 22px;
# 				letter-spacing: 0px;
# 				font-weight: normal;
# 			}a.read-more, input[type=submit], .hb-caption-layer .hb-button, .hb-push-button-text, #pre-footer-area .hb-button, .hb-button, .hb-single-next-prev .text-inside, #main-wrapper .coupon-code input.button,#main-wrapper .form-row input.button,#main-wrapper input.checkout-button,#main-wrapper input.hb-update-cart,.woocommerce-page #main-wrapper .shipping-calculator-form-hb button.button { font-weight: 700; letter-spacing: 1px }#hb-side-menu li a, #main-nav ul.sub-menu li a, #main-nav ul.sub-menu ul li a, #main-nav, #main-nav li a, .light-menu-dropdown #main-nav > li.megamenu > ul.sub-menu > li > a, #main-nav > li.megamenu > ul.sub-menu > li > a {
# 				font-family: "Open Sans", sans-serif;
# 				font-size: 16px;
# 				letter-spacing: 0px;
# 				font-weight: normal;
# 				text-transform: none;
# 			}#main-nav ul.sub-menu li a, #hb-side-menu ul.sub-menu li a, #main-nav ul.sub-menu ul li a, ul.sub-menu .widget-item h4, #main-nav > li.megamenu > ul.sub-menu > li > a #main-nav > li.megamenu > ul.sub-menu > li > a, #main-nav > li.megamenu > ul.sub-menu > li > a {
# 				font-family: "Open Sans", sans-serif;
# 				font-size: 15px;
# 				letter-spacing: 0px;
# 				font-weight: ;
# 				text-transform: none;
# 			}#copyright-wrapper, #copyright-wrapper a {
# 				font-family: "Cabin Condensed", sans-serif;
# 				font-size: 14px;
# 				line-height: 22px;
# 				letter-spacing: 0px;
# 				font-weight: normal;
# 			}h1, article.single h1.title, #hb-page-title .light-text h1, #hb-page-title .dark-text h1 {
# 				font-family: "Open Sans", sans-serif;
# 				font-size: 26px;
# 				line-height: 28px;
# 				letter-spacing: 0px;
# 				font-weight: 700;
# 			}h2, #hb-page-title h2, .post-content h2.title {
# 				font-family: "Open Sans", sans-serif;
# 				font-size: 22px;
# 				line-height: 26px;
# 				letter-spacing: 0px;
# 				font-weight: 700;
# 			}h3, h3.title-class, .hb-callout-box h3, .hb-gal-standard-description h3 {
# 				font-family: "Open Sans", sans-serif;
# 				font-size: 20px;
# 				line-height: 24px;
# 				letter-spacing: 0px;
# 				font-weight: 700;
# 			}h4, .widget-item h4, #respond h3, .content-box h4, .feature-box h4.bold {
# 				font-family: "Open Sans", sans-serif;
# 				font-size: 18px;
# 				line-height: 22px;
# 				letter-spacing: 0px;
# 				font-weight: 700;
# 			}h5, #comments h5, #respond h5, .testimonial-author h5 {
# 				font-family: "Open Sans", sans-serif;
# 				font-size: 16px;
# 				line-height: 20px;
# 				letter-spacing: 0px;
# 				font-weight: 700;
# 			}	</style>
# <title>Events Archive - Loudoun Wildlife Conservancy</title>
# </meta></meta></meta></meta></meta></meta></head>
# <!-- END head -->
# <!-- START body -->
# <body class="archive post-type-archive post-type-archive-tribe_events hb-preloader disable-native-prettyphoto hb-stretched-layout tribe-no-js tribe-filter-live tribe-events-uses-geolocation wpb-js-composer js-comp-ver-6.0.5 vc_responsive events-gridview events-archive tribe-events-style-full tribe-events-style-theme tribe-theme-parent-HighendWP tribe-theme-child-HighendWP-child tribe-events-page-template" data-fixed-footer="0" itemscope="itemscope" itemtype="http://schema.org/WebPage">
# <div id="mobile-menu-wrap"><form action="https://loudounwildlife.org/" class="mobile-search-form" method="get"><input autocomplete="off" name="s" placeholder="Search" type="text"/></form><a class="mobile-menu-close"><i class="hb-icon-x"></i></a><nav class="clearfix interactive" id="mobile-menu"><div class="menu-main-menu-container"><ul class="menu-main-menu-container" id="menu-main-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-28224" id="menu-item-28224"><a href="https://loudounwildlife.org/">Home</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-24" id="menu-item-24"><a href="https://loudounwildlife.org/about-us/">About Us</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-542" id="menu-item-542"><a href="https://loudounwildlife.org/about-us/">Mission &amp; Vision</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-543" id="menu-item-543"><a href="https://loudounwildlife.org/about-us/board-of-directors/">Board of Directors</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-599" id="menu-item-599"><a href="https://loudounwildlife.org/about-us/operationsteam/">Operations Team</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-25764" id="menu-item-25764"><a href="https://loudounwildlife.org/our-partners/">Our Partners</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-26218" id="menu-item-26218"><a href="https://loudounwildlife.org/about-us/contributing-photographers/">Contributing Photographers</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom current-menu-item current-menu-item current_page_item menu-item-347" id="menu-item-347"><a aria-current="page" href="https://loudounwildlife.org/events/">Events</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-22" id="menu-item-22"><a href="https://loudounwildlife.org/our-work/">Our Work</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-253" id="menu-item-253"><a href="https://loudounwildlife.org/programs-and-field-trips/">Programs and Field Trips</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-252" id="menu-item-252"><a href="https://loudounwildlife.org/citizen-science/">Citizen Science</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-250" id="menu-item-250"><a href="https://loudounwildlife.org/habitat-restoration/">Habitat Restoration</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-251" id="menu-item-251"><a href="https://loudounwildlife.org/conservation-advocacy/">Conservation Advocacy</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-28121" id="menu-item-28121"><a href="https://loudounwildlife.org/black-oak/">JK Black Oak Wildlife Sanctuary</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-26552" id="menu-item-26552"><a href="https://loudoun-wildlife-conservancy.weebly.com/home">Store</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-90" id="menu-item-90"><a href="https://loudounwildlife.org/library/">Library</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-270" id="menu-item-270"><a href="https://loudounwildlife.org/volunteer/">Volunteer</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-27635" id="menu-item-27635"><a href="https://loudounwildlife.org/volunteer/">Volunteer opportunities</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-27632" id="menu-item-27632"><a href="https://loudounwildlife.org/2017/01/volunteer-application/">Volunteer application</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-27637" id="menu-item-27637"><a href="https://loudounwildlife.org/2019/01/volunteer-waiver-form/">Waiver form</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-27638" id="menu-item-27638"><a href="https://loudounwildlife.org/2018/11/volunteer-hours/">Volunteer hours</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-92" id="menu-item-92"><a href="https://loudounwildlife.org/contact-us/">Contact</a></li>
# <li class="tdp-mobile-only menu-item menu-item-type-post_type menu-item-object-page menu-item-24756" id="menu-item-24756"><a href="https://loudounwildlife.org/email-sign-up/">Stay Informed!</a></li>
# <li class="tdp-mobile-only menu-item menu-item-type-post_type menu-item-object-page menu-item-91" id="menu-item-91"><a href="https://loudounwildlife.org/donate/">Join/Donate</a></li>
# </ul></div></nav></div><!-- END #mobile-menu-wrap -->
# <!-- BEGIN #hb-wrap -->
# <div id="hb-wrap">
# <!-- BEGIN #main-wrapper -->
# <div class="hb-stretched-layout hb_boxed_layout_regular with-shadow fw-100 hb-responsive nav-type-1" data-cart-count="" data-cart-url="" data-search-header="1" id="main-wrapper">
# <!-- BEGIN #hb-header -->
# <header class="" id="hb-header">
# <!-- BEGIN #header-bar -->
# <div class="style-1 clearfix" id="header-bar">
# <!-- BEGIN .container or .container-wide -->
# <div class="container">
# <!-- BEGIN .top-widget Information -->
# <div class="top-widget float-left" id="top-info-widget">
# <p><i class="hb-moon-arrow-right-5"></i><a href="/donate/">Join/Donate</a></p>
# </div>
# <!-- END .top-widget -->
# <!-- BEGIN .top-widget Email -->
# <div class="top-widget float-left clear-r-margin">
# <a href="mailto:info@loudounwildlife.org"><i class="hb-moon-envelop"></i>info@loudounwildlife.org</a>
# </div>
# <!-- END .top-widget -->
# <!-- BEGIN .top-widget Custom Link -->
# <div class="top-widget float-right" id="top-custom-link-widget">
# <a href="/email-sign-up/"><i class="hb-moon-envelop-opened"></i>Stay Informed!</a>
# </div>
# <!-- END .top-widget -->
# <!-- BEGIN .top-widget -->
# <div class="top-widget float-right social-list" id="top-socials-widget">
# <ul class="clearfix">
# <li>
# <a href="https://www.facebook.com/LoudounWildlife/" original-title="Facebook" target="_blank"><i class="hb-moon-facebook"></i></a>
# </li>
# <li>
# <a href="https://twitter.com/loudounwildlife" original-title="Twitter" target="_blank"><i class="hb-moon-twitter"></i></a>
# </li>
# <li>
# <a href="https://www.instagram.com/loudounwildlife/" original-title="Instagram" target="_blank"><i class="hb-moon-instagram"></i></a>
# </li>
# <li>
# <a href="mailto:contact@loudounwildlife.org" original-title="Envelop" target="_blank"><i class="hb-moon-envelop"></i></a>
# </li>
# <li>
# <a href="https://loudounwildlife.org/category/wildlife-news/feed/" original-title="Feed-2" target="_blank"><i class="hb-moon-feed-2"></i></a>
# </li>
# </ul>
# </div>
# <!-- END .top-widget -->
# </div>
# <!-- END .container or .container-wide -->
# </div>
# <!-- END #header-bar -->
# <div id="header-dropdown">
# <div data-api-key="" data-map-buttons="1" data-map-img="" data-map-lat="48.856614" data-map-level="16" data-map-lng="2.352222" data-overlay-color="#ff6838" id="contact-map"></div>
# <div class="close-map"><i class="hb-moon-close-2"></i></div>
# </div> <style type="text/css">
#     #logo img,.stuck #logo img {max-height:60px;}
#     </style>
# <!-- BEGIN #header-inner -->
# <div class="nav-type-1 hb-ajax-search clearfix" data-height="70" id="header-inner" itemscope="itemscope" itemtype="https://schema.org/WPHeader" role="banner" style="height: 70px; line-height: 70px;">
# <!-- BEGIN #header-inner-bg -->
# <div id="header-inner-bg">
# <!-- BEGIN .container or .container-wide -->
# <div class="container">
# <!-- BEGIN #logo -->
# <div id="logo" style="height:70px; line-height: 70px;">
# <a class="image-logo" href="https://loudounwildlife.org">
# <span class="hb-dark-logo hb-visible-logo hb-logo-wrap">
# <img alt="Loudoun Wildlife Conservancy" class="default" height="72" src="https://loudounwildlife.org/wp-content/uploads/2016/08/layout__logo-loudon-1x.png" width="318"/>
# <img alt="Loudoun Wildlife Conservancy" class="retina" height="144" src="https://loudounwildlife.org/wp-content/uploads/2016/08/layout__logo-loudon-2x.png" width="636"/>
# </span>
# </a>
# </div>
# <!-- END #logo -->
# <!-- BEGIN .main-navigation -->
# <nav class="main-navigation minimal-skin hb-effect-4 light-menu-dropdown clearfix" data-height="70" itemscope="itemscope" itemtype="https://schema.org/SiteNavigationElement" role="navigation" style="height: 70px; line-height: 70px;">
# <ul class="sf-menu" id="main-nav"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-28224"><a href="https://loudounwildlife.org/"><span>Home</span></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-24"><a href="https://loudounwildlife.org/about-us/"><span>About Us</span></a>
# <ul class="sub-menu" style="">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-542"><a href="https://loudounwildlife.org/about-us/"><span>Mission &amp; Vision</span></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-543"><a href="https://loudounwildlife.org/about-us/board-of-directors/"><span>Board of Directors</span></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-599"><a href="https://loudounwildlife.org/about-us/operationsteam/"><span>Operations Team</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-25764"><a href="https://loudounwildlife.org/our-partners/"><span>Our Partners</span></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-26218"><a href="https://loudounwildlife.org/about-us/contributing-photographers/"><span>Contributing Photographers</span></a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom current-menu-item current-menu-item current_page_item menu-item-347"><a href="https://loudounwildlife.org/events/"><span>Events</span></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-22"><a href="https://loudounwildlife.org/our-work/"><span>Our Work</span></a>
# <ul class="sub-menu" style="">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-253"><a href="https://loudounwildlife.org/programs-and-field-trips/"><span>Programs and Field Trips</span></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-252"><a href="https://loudounwildlife.org/citizen-science/"><span>Citizen Science</span></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-250"><a href="https://loudounwildlife.org/habitat-restoration/"><span>Habitat Restoration</span></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-251"><a href="https://loudounwildlife.org/conservation-advocacy/"><span>Conservation Advocacy</span></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-28121"><a href="https://loudounwildlife.org/black-oak/"><span>JK Black Oak Wildlife Sanctuary</span></a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-26552"><a href="https://loudoun-wildlife-conservancy.weebly.com/home"><span>Store</span></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-90"><a href="https://loudounwildlife.org/library/"><span>Library</span></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-270"><a href="https://loudounwildlife.org/volunteer/"><span>Volunteer</span></a>
# <ul class="sub-menu" style="">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-27635"><a href="https://loudounwildlife.org/volunteer/"><span>Volunteer opportunities</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-27632"><a href="https://loudounwildlife.org/2017/01/volunteer-application/"><span>Volunteer application</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-27637"><a href="https://loudounwildlife.org/2019/01/volunteer-waiver-form/"><span>Waiver form</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-27638"><a href="https://loudounwildlife.org/2018/11/volunteer-hours/"><span>Volunteer hours</span></a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-92"><a href="https://loudounwildlife.org/contact-us/"><span>Contact</span></a></li>
# <li class="tdp-mobile-only menu-item menu-item-type-post_type menu-item-object-page menu-item-24756"><a href="https://loudounwildlife.org/email-sign-up/"><span>Stay Informed!</span></a></li>
# <li class="tdp-mobile-only menu-item menu-item-type-post_type menu-item-object-page menu-item-91"><a href="https://loudounwildlife.org/donate/"><span>Join/Donate</span></a></li>
# </ul>
# <!-- BEGIN #fancy-search -->
# <div id="fancy-search">
# <form action="https://loudounwildlife.org/" autocomplete="off" id="fancy-search-form" novalidate="">
# <input autocomplete="off" id="s" name="s" placeholder="Type keywords and press enter" type="text"/>
# </form>
# <a class="no-transition" href="#" id="close-fancy-search"><i class="hb-icon-x"></i></a>
# <span class="spinner"></span>
# </div>
# <!-- END #fancy-serach -->
# <a href="#" id="show-nav-menu"><i class="icon-bars"></i></a>
# </nav>
# <!-- END .main-navigation -->
# </div>
# <!-- END .container or .container-wide -->
# </div>
# <!-- END #header-inner-bg -->
# </div>
# <!-- END #header-inner -->
# </header>
# <!-- END #hb-header -->
# <!-- BEGIN #slider-section -->
# <div class="clearfix" id="slider-section" style="">
# <canvas id="hb-canvas-effect"></canvas>
# </div>
# <!-- END #slider-section --> <main class="tribe-events-pg-template" id="tribe-events-pg-template">
# <div class="tribe-no-js" data-category="" data-datepicker_format="0" data-featured="" data-live_ajax="1" id="tribe-events"><div class="tribe-events-before-html"><p style="text-align: center;"><img alt="events-banner-with-type" class="alignnone size-full wp-image-13864" height="450" src="https://loudounwildlife.org/wp-content/uploads/2016/09/Events-banner-with-type.jpg" width="1999"/><br/>
# Click on calendar events to go to the event detail page for more information and registration.</p>
# </div><span class="tribe-events-ajax-loading"><img alt="Loading Events" class="tribe-events-spinner-medium" src="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/src/resources/images/tribe-loading.gif"/></span> <div class="tribe-clearfix" id="tribe-events-content-wrapper"><input id="tribe-events-list-hash" type="hidden" value=""/>
# <div class="tribe-events-title-bar">
# <!-- Month Title -->
# <h1 class="tribe-events-page-title">Events for December 2019</h1>
# </div>
# <div id="tribe-events-bar">
# <h2 class="tribe-events-visuallyhidden">Events Search and Views Navigation</h2>
# <form action="https://loudounwildlife.org/events?post_type=tribe_events&amp;eventDisplay=default" class="tribe-clearfix tribe-events-bar--has-filters tribe-events-bar--has-views" id="tribe-bar-form" method="post" name="tribe-bar-form">
# <div id="tribe-bar-filters-wrap">
# <button aria-controls="tribe-bar-filters" aria-expanded="false" data-label-hidden="Show Events Search" data-label-shown="Hide Events Search" id="tribe-bar-collapse-toggle" type="button">
# <span class="tribe-bar-toggle-text">
# 						Show Events Search					</span>
# <span class="tribe-bar-toggle-arrow"></span>
# </button>
# <div aria-hidden="true" class="tribe-bar-filters" id="tribe-bar-filters">
# <div class="tribe-bar-filters-inner tribe-clearfix">
# <h3 class="tribe-events-visuallyhidden">Events Search</h3>
# <div class="tribe-bar-date-filter">
# <label class="label-tribe-bar-date" for="tribe-bar-date">Events In</label>
# <input aria-label="Search for Events by month. Please use the format 4 digit year hyphen 2 digit month." id="tribe-bar-date" name="tribe-bar-date" placeholder="Date" style="position: relative;" type="text" value="2019-12"/><input class="tribe-no-param" id="tribe-bar-date-day" name="tribe-bar-date-day" type="hidden" value=""/> </div>
# <div class="tribe-bar-search-filter">
# <label class="label-tribe-bar-search" for="tribe-bar-search">Search</label>
# <input aria-label="Search for Events by Keyword." id="tribe-bar-search" name="tribe-bar-search" placeholder="Keyword" type="text" value=""/> </div>
# <div class="tribe-bar-geoloc-filter">
# <label class="label-tribe-bar-geoloc" for="tribe-bar-geoloc">Near</label>
# <input id="tribe-bar-geoloc-lat" name="tribe-bar-geoloc-lat" type="hidden" value=""><input id="tribe-bar-geoloc-lng" name="tribe-bar-geoloc-lng" type="hidden" value=""><input id="tribe-bar-geoloc" name="tribe-bar-geoloc" placeholder="Location" type="text" value=""/> </input></input></div>
# <div class="tribe-bar-submit">
# <input aria-label="Submit Events search" class="tribe-events-button tribe-no-param" name="submit-bar" type="submit" value="Find Events">
# </input></div>
# </div>
# </div>
# </div>
# <div class="tribe-bar-views" id="tribe-bar-views">
# <div class="tribe-bar-views-inner tribe-clearfix">
# <h3 class="tribe-events-visuallyhidden">Event Views Navigation</h3>
# <label aria-label="View Events As" id="tribe-bar-views-label">
# 						View As					</label>
# <select aria-label="View Events As" class="tribe-bar-views-select tribe-no-param" name="tribe-bar-view">
# <option data-view="list" value="https://loudounwildlife.org/events/list/">List</option><option data-view="month" selected="" value="https://loudounwildlife.org/events/month/">Month</option><option data-view="week" value="https://loudounwildlife.org/events/week/">Week</option><option data-view="day" value="https://loudounwildlife.org/events/today/">Day</option><option data-view="map" value="https://loudounwildlife.org/events/map/">Map</option><option data-view="photo" value="https://loudounwildlife.org/events/photo/">Photo</option> </select>
# </div>
# </div>
# </form>
# </div>
# <div class="tribe-events-month" id="tribe-events-content">
# <!-- Notices -->
# <!-- Month Header -->
# ...
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-27632"><a href="https://loudounwildlife.org/2017/01/volunteer-application/">Volunteer application</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-27637"><a href="https://loudounwildlife.org/2019/01/volunteer-waiver-form/">Waiver form</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-27638"><a href="https://loudounwildlife.org/2018/11/volunteer-hours/">Volunteer hours</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-92"><a href="https://loudounwildlife.org/contact-us/">Contact</a></li>
# <li class="tdp-mobile-only menu-item menu-item-type-post_type menu-item-object-page menu-item-24756"><a href="https://loudounwildlife.org/email-sign-up/">Stay Informed!</a></li>
# <li class="tdp-mobile-only menu-item menu-item-type-post_type menu-item-object-page menu-item-91"><a href="https://loudounwildlife.org/donate/">Join/Donate</a></li>
# </ul></div>
# </div><!-- END .container -->
# </div><!-- END #copyright-wrapper -->
# </div><!-- END #main-wrapper -->
# </div><!-- END #hb-wrap -->
# <div id="hb-modal-overlay"></div> <script type="text/javascript">
# 		jQuery(document).ready(function() {
# 			var gethost = new RegExp(location.host);
# 			jQuery("a[href$='.pdf']").each(function() {
# 				if(gethost.test(jQuery(this).attr('href'))){
# 			   		var _href = jQuery(this).attr("href");
# 			   		jQuery(this).attr("href", 'https://loudounwildlife.org/themencode-pdf-viewer/?file='+ _href);
# 			   	} else {
# 			   		// Do Nothing
# 			   	}
# 			});
# 		});
# 	</script>
# <script type="text/javascript">jQuery(function($) {jQuery('a[href$=".pdf"]').attr('target', '_blank');});</script> <script>
# 		( function ( body ) {
# 			'use strict';
# 			body.className = body.className.replace( /\btribe-no-js\b/, 'tribe-js' );
# 		} )( document.body );
# 		</script>
# <script>
#   		jQuery(function($) {
#
#     		  console.log('password trigger');
#
#     		$('label[for="password"], label[for="password_current"], label[for="password_1"], label[for="password_2"]').after('<a class="woocommerce-password-toggle">Show</a>');
#
#         $('.woocommerce-password-toggle').on('click', function(e){
#             e.preventDefault();
#             if( $(this).hasClass('woocommerce-password-show') ){
#               $(this).removeClass('woocommerce-password-show').text('Show').next('input').attr('type', 'password');
#             } else {
#               $(this).addClass('woocommerce-password-show').text('Hide').next('input').attr('type', 'text');
#             }
#           });
#       });
#     </script>
# <script> /* <![CDATA[ */var tribe_l10n_datatables = {"aria":{"sort_ascending":": activate to sort column ascending","sort_descending":": activate to sort column descending"},"length_menu":"Show _MENU_ entries","empty_table":"No data available in table","info":"Showing _START_ to _END_ of _TOTAL_ entries","info_empty":"Showing 0 to 0 of 0 entries","info_filtered":"(filtered from _MAX_ total entries)","zero_records":"No matching records found","search":"Search:","all_selected_text":"All items on this page were selected. ","select_all_link":"Select all pages","clear_selection":"Clear Selection.","pagination":{"all":"All","next":"Next","previous":"Previous"},"select":{"rows":{"0":"","_":": Selected %d rows","1":": Selected 1 row"}},"datepicker":{"dayNames":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"dayNamesShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"dayNamesMin":["S","M","T","W","T","F","S"],"monthNames":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesShort":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesMin":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"nextText":"Next","prevText":"Prev","currentText":"Today","closeText":"Done","today":"Today","clear":"Clear"}};/* ]]> */ </script><link href="//fonts.googleapis.com/css?family=Open+Sans%3Anormal%2C700&amp;subset=latin&amp;ver=5.3" id="Open+Sans-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//fonts.googleapis.com/css?family=Cabin+Condensed%3Anormal&amp;subset=latin&amp;ver=5.3" id="Cabin+Condensed-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://loudounwildlife.org/wp-content/plugins/events-calendar-pro/src/resources/css/widget-theme.min.css?ver=4.7.10" id="widget-calendar-pro-style-css" media="all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# /* <![CDATA[ */
# var TribeCalendar = {"ajaxurl":"https:\/\/loudounwildlife.org\/wp-admin\/admin-ajax.php","post_type":"tribe_events"};
# /* ]]> */
# </script>
# <script src="https://loudounwildlife.org/wp-content/plugins/the-events-calendar/src/resources/js/tribe-events-ajax-calendar.min.js?ver=4.9.13" type="text/javascript"></script>
# <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyBtfliC9HhwvC6lSsyBhx9TtaZS1BiZ9A8&amp;ver=4.9.13" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var GeoLoc = {"ajaxurl":"https:\/\/loudounwildlife.org\/wp-admin\/admin-ajax.php","nonce":"a46472a166","map_view":"","pin_url":""};
# var GeoLoc = {"ajaxurl":"https:\/\/loudounwildlife.org\/wp-admin\/admin-ajax.php","nonce":"a46472a166","map_view":"","pin_url":""};
# /* ]]> */
# </script>
# <script src="https://loudounwildlife.org/wp-content/plugins/events-calendar-pro/src/resources/js/tribe-events-ajax-maps.min.js?ver=4.7.10" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"https:\/\/loudounwildlife.org\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"}};
# /* ]]> */
# </script>
# <script src="https://loudounwildlife.org/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=5.1.6" type="text/javascript"></script>
# <script defer="defer" src="https://loudounwildlife.org/wp-content/plugins/essential-grid/public/assets/js/jquery.themepunch.tools.min.js?ver=2.3.2" type="text/javascript"></script>
# <script defer="defer" src="https://loudounwildlife.org/wp-content/plugins/revslider/public/assets/js/jquery.themepunch.revolution.min.js?ver=5.4.8.3" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var socialsnap_script = {"ajaxurl":"https:\/\/loudounwildlife.org\/wp-admin\/admin-ajax.php","on_media_width":"250","on_media_height":"250","nonce":"0bbf10b557","post_id":"0"};
# /* ]]> */
# </script>
# <script src="https://loudounwildlife.org/wp-content/plugins/socialsnap/assets/js/socialsnap.js?ver=1.1.7" type="text/javascript"></script>
# <script type="text/javascript">
# var renderInvisibleReCaptcha = function() {
#
#     for (var i = 0; i < document.forms.length; ++i) {
#         var form = document.forms[i];
#         var holder = form.querySelector('.inv-recaptcha-holder');
#
#         if (null === holder) continue;
# 		holder.innerHTML = '';
#
#          (function(frm){
# 			var cf7SubmitElm = frm.querySelector('.wpcf7-submit');
#             var holderId = grecaptcha.render(holder,{
#                 'sitekey': '6Le9ExsUAAAAAHkBC0rZX0eJNirX1dUjSIGRWVEw', 'size': 'invisible', 'badge' : 'bottomright',
#                 'callback' : function (recaptchaToken) {
# 					if((null !== cf7SubmitElm) && (typeof jQuery != 'undefined')){jQuery(frm).submit();grecaptcha.reset(holderId);return;}
# 					 HTMLFormElement.prototype.submit.call(frm);
#                 },
#                 'expired-callback' : function(){grecaptcha.reset(holderId);}
#             });
#
# 			if(null !== cf7SubmitElm && (typeof jQuery != 'undefined') ){
# 				jQuery(cf7SubmitElm).off('click').on('click', function(clickEvt){
# 					clickEvt.preventDefault();
# 					grecaptcha.execute(holderId);
# 				});
# 			}
# 			else
# 			{
# 				frm.onsubmit = function (evt){evt.preventDefault();grecaptcha.execute(holderId);};
# 			}
#
#
#         })(form);
#     }
# };
# </script>
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js?onload=renderInvisibleReCaptcha&amp;render=explicit" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-content/themes/HighendWP/assets/js/scripts.js?ver=3.6.2" type="text/javascript"></script>
# <script src="//www.google.com/jsapi?ver=3.6.2" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var hb_gmap = {"1":{"lat":"48.856614","lng":"2.352222","ibx":"Enter your info here or leave it empty."}};
# /* ]]> */
# </script>
# <script src="https://loudounwildlife.org/wp-content/themes/HighendWP/assets/js/map.js?ver=3.6.2" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-content/themes/HighendWP/assets/js/mediaelement/mediaelement.js?ver=3.6.2" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-content/themes/HighendWP/assets/js/jquery.flexslider.js?ver=3.6.2" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-content/themes/HighendWP/assets/js/jquery.validate.js?ver=3.6.2" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-content/themes/HighendWP/assets/js/jquery.easychart.js?ver=3.6.2" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-content/themes/HighendWP/assets/js/responsivecarousel.min.js?ver=3.6.2" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-content/themes/HighendWP/assets/js/jquery.owl.carousel.min.js?ver=3.6.2" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-includes/js/jquery/ui/core.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-includes/js/jquery/ui/widget.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-includes/js/jquery/ui/position.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-includes/js/jquery/ui/menu.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-includes/js/dist/vendor/wp-polyfill.min.js?ver=7.4.4" type="text/javascript"></script>
# <script type="text/javascript">
# ( 'fetch' in window ) || document.write( '<script src="https://loudounwildlife.org/wp-includes/js/dist/vendor/wp-polyfill-fetch.min.js?ver=3.0.0"></scr' + 'ipt>' );( document.contains ) || document.write( '<script src="https://loudounwildlife.org/wp-includes/js/dist/vendor/wp-polyfill-node-contains.min.js?ver=3.26.0-0"></scr' + 'ipt>' );( window.FormData && window.FormData.prototype.keys ) || document.write( '<script src="https://loudounwildlife.org/wp-includes/js/dist/vendor/wp-polyfill-formdata.min.js?ver=3.0.12"></scr' + 'ipt>' );( Element.prototype.matches && Element.prototype.closest ) || document.write( '<script src="https://loudounwildlife.org/wp-includes/js/dist/vendor/wp-polyfill-element-closest.min.js?ver=2.0.2"></scr' + 'ipt>' );
# </script>
# <script src="https://loudounwildlife.org/wp-includes/js/dist/dom-ready.min.js?ver=2.5.1" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-includes/js/dist/a11y.min.js?ver=2.5.1" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var uiAutocompleteL10n = {"noResults":"No results found.","oneResult":"1 result found. Use up and down arrow keys to navigate.","manyResults":"%d results found. Use up and down arrow keys to navigate.","itemSelected":"Item selected."};
# /* ]]> */
# </script>
# <script src="https://loudounwildlife.org/wp-includes/js/jquery/ui/autocomplete.min.js?ver=1.11.4" type="text/javascript"></script>
# <script charset="utf8" src="https://loudounwildlife.org/wp-content/themes/HighendWP/assets/js/jquery.pace.js?ver=3.6.2" type="text/javascript"></script>
# <script type="text/javascript">
# var mejsL10n = {"language":"en","strings":{"mejs.install-flash":"You are using a browser that does not have Flash player enabled or installed. Please turn on your Flash player plugin or download the latest version from https:\/\/get.adobe.com\/flashplayer\/","mejs.fullscreen-off":"Turn off Fullscreen","mejs.fullscreen-on":"Go Fullscreen","mejs.download-video":"Download Video","mejs.fullscreen":"Fullscreen","mejs.time-jump-forward":["Jump forward 1 second","Jump forward %1 seconds"],"mejs.loop":"Toggle Loop","mejs.play":"Play","mejs.pause":"Pause","mejs.close":"Close","mejs.time-slider":"Time Slider","mejs.time-help-text":"Use Left\/Right Arrow keys to advance one second, Up\/Down arrows to advance ten seconds.","mejs.time-skip-back":["Skip back 1 second","Skip back %1 seconds"],"mejs.captions-subtitles":"Captions\/Subtitles","mejs.captions-chapters":"Chapters","mejs.none":"None","mejs.mute-toggle":"Mute Toggle","mejs.volume-help-text":"Use Up\/Down Arrow keys to increase or decrease volume.","mejs.unmute":"Unmute","mejs.mute":"Mute","mejs.volume-slider":"Volume Slider","mejs.video-player":"Video Player","mejs.audio-player":"Audio Player","mejs.ad-skip":"Skip ad","mejs.ad-skip-info":["Skip in 1 second","Skip in %1 seconds"],"mejs.source-chooser":"Source Chooser","mejs.stop":"Stop","mejs.speed-rate":"Speed Rate","mejs.live-broadcast":"Live Broadcast","mejs.afrikaans":"Afrikaans","mejs.albanian":"Albanian","mejs.arabic":"Arabic","mejs.belarusian":"Belarusian","mejs.bulgarian":"Bulgarian","mejs.catalan":"Catalan","mejs.chinese":"Chinese","mejs.chinese-simplified":"Chinese (Simplified)","mejs.chinese-traditional":"Chinese (Traditional)","mejs.croatian":"Croatian","mejs.czech":"Czech","mejs.danish":"Danish","mejs.dutch":"Dutch","mejs.english":"English","mejs.estonian":"Estonian","mejs.filipino":"Filipino","mejs.finnish":"Finnish","mejs.french":"French","mejs.galician":"Galician","mejs.german":"German","mejs.greek":"Greek","mejs.haitian-creole":"Haitian Creole","mejs.hebrew":"Hebrew","mejs.hindi":"Hindi","mejs.hungarian":"Hungarian","mejs.icelandic":"Icelandic","mejs.indonesian":"Indonesian","mejs.irish":"Irish","mejs.italian":"Italian","mejs.japanese":"Japanese","mejs.korean":"Korean","mejs.latvian":"Latvian","mejs.lithuanian":"Lithuanian","mejs.macedonian":"Macedonian","mejs.malay":"Malay","mejs.maltese":"Maltese","mejs.norwegian":"Norwegian","mejs.persian":"Persian","mejs.polish":"Polish","mejs.portuguese":"Portuguese","mejs.romanian":"Romanian","mejs.russian":"Russian","mejs.serbian":"Serbian","mejs.slovak":"Slovak","mejs.slovenian":"Slovenian","mejs.spanish":"Spanish","mejs.swahili":"Swahili","mejs.swedish":"Swedish","mejs.tagalog":"Tagalog","mejs.thai":"Thai","mejs.turkish":"Turkish","mejs.ukrainian":"Ukrainian","mejs.vietnamese":"Vietnamese","mejs.welsh":"Welsh","mejs.yiddish":"Yiddish"}};
# </script>
# <script src="https://loudounwildlife.org/wp-includes/js/mediaelement/mediaelement-and-player.min.js?ver=4.2.13-9993131" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-includes/js/mediaelement/mediaelement-migrate.min.js?ver=5.3" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var _wpmejsSettings = {"pluginPath":"\/wp-includes\/js\/mediaelement\/","classPrefix":"mejs-","stretching":"responsive"};
# /* ]]> */
# </script>
# <script src="https://loudounwildlife.org/wp-includes/js/mediaelement/wp-mediaelement.min.js?ver=5.3" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var highend_vars = {"ajaxurl":"https:\/\/loudounwildlife.org\/wp-admin\/admin-ajax.php","nonce":"f10516b2b5","paged":"2","search_header":"1","cart_url":"","cart_count":"","responsive":"1","texts":{"load-more":"Load More Posts","no-more-posts":"No More Posts"}};
# /* ]]> */
# </script>
# <script src="https://loudounwildlife.org/wp-content/themes/HighendWP/assets/js/jquery.custom.js?ver=3.6.2" type="text/javascript"></script>
# <script src="https://loudounwildlife.org/wp-includes/js/wp-embed.min.js?ver=5.3" type="text/javascript"></script>
# </body>
# </html>

# %%
soup
# Out:
# <function __main__.soupify_event_page(url='https://anshome.org/events-calendar/')>

# %%
BeautifulSoup(content, 'html.parser')
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 7]>
# <html class="ie ie7" lang="en-US">
# <![endif]-->
# <!--[if IE 8]>
# <html class="ie ie8" lang="en-US">
# <![endif]-->
# <!--[if !(IE 7) & !(IE 8)]><!-->
# <html lang="en-US">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width" name="viewport"/>
# <title>EVENTS | Nature for all | Audubon Naturalist Society</title>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://anshome.org/xmlrpc.php" rel="pingback"/>
# <!--[if lt IE 9]>
# <script src="https://anshome.org/wp-content/themes/twentytwelve/js/html5.js" type="text/javascript"></script>
# <![endif]-->
# <!-- All in One SEO Pack 2.10 by Michael Torbert of Semper Fi Web Designob_start_detected [-1,-1] -->
# <meta content="Audubon Naturalist Society offers a variety of outdoor adventures and environmental education programs promoting nature for all in the Washington, D.C. region." name="description"/>
# <link href="https://anshome.org/events-calendar/" rel="canonical"/>
# <!-- /all in one seo pack -->
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://anshome.org/feed/" rel="alternate" title="Audubon Naturalist Society » Feed" type="application/rss+xml"/>
# <!-- This site uses the Google Analytics by MonsterInsights plugin v7.3.2 - Using Analytics tracking - https://www.monsterinsights.com/ -->
# <script data-cfasync="false" type="text/javascript">
# 	var mi_version         = '7.3.2';
# 	var mi_track_user      = true;
# 	var mi_no_track_reason = '';
#
# 	var disableStr = 'ga-disable-UA-98464126-1';
#
# 	/* Function to detect opted out users */
# 	function __gaTrackerIsOptedOut() {
# 		return document.cookie.indexOf(disableStr + '=true') > -1;
# 	}
#
# 	/* Disable tracking if the opt-out cookie exists. */
# 	if ( __gaTrackerIsOptedOut() ) {
# 		window[disableStr] = true;
# 	}
#
# 	/* Opt-out function */
# 	function __gaTrackerOptout() {
# 	  document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 	  window[disableStr] = true;
# 	}
#
# 	if ( mi_track_user ) {
# 		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 			(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 			m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','//www.google-analytics.com/analytics.js','__gaTracker');
#
# 		__gaTracker('create', 'UA-98464126-1', 'auto');
# 		__gaTracker('set', 'forceSSL', true);
# 		__gaTracker('require', 'displayfeatures');
# 		__gaTracker('require', 'linkid', 'linkid.js');
# 		__gaTracker('send','pageview');
# 	} else {
# 		console.log( "" );
# 		(function() {
# 			/* https://developers.google.com/analytics/devguides/collection/analyticsjs/ */
# 			var noopfn = function() {
# 				return null;
# 			};
# 			var noopnullfn = function() {
# 				return null;
# 			};
# 			var Tracker = function() {
# 				return null;
# 			};
# 			var p = Tracker.prototype;
# 			p.get = noopfn;
# 			p.set = noopfn;
# 			p.send = noopfn;
# 			var __gaTracker = function() {
# 				var len = arguments.length;
# 				if ( len === 0 ) {
# 					return;
# 				}
# 				var f = arguments[len-1];
# 				if ( typeof f !== 'object' || f === null || typeof f.hitCallback !== 'function' ) {
# 					console.log( 'Not running function __gaTracker(' + arguments[0] + " ....) because you are not being tracked. " + mi_no_track_reason );
# 					return;
# 				}
# 				try {
# 					f.hitCallback();
# 				} catch (ex) {
#
# 				}
# 			};
# 			__gaTracker.create = function() {
# 				return new Tracker();
# 			};
# 			__gaTracker.getByName = noopnullfn;
# 			__gaTracker.getAll = function() {
# 				return [];
# 			};
# 			__gaTracker.remove = noopfn;
# 			window['__gaTracker'] = __gaTracker;
# 					})();
# 		}
# </script>
# <!-- / Google Analytics by MonsterInsights -->
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/anshome.org\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.3.1"}};
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://anshome.org/wp-includes/css/dist/block-library/style.min.css?ver=5.3.1" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://anshome.org/wp-content/plugins/accordions/assets/global/css/themesTabs.style.css?ver=5.3.1" id="accordions_themes.Tabs.style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://anshome.org/wp-content/plugins/siteorigin-panels/css/front-flex.min.css?ver=2.9.5" id="siteorigin-panels-front-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://anshome.org/wp-content/uploads/siteorigin-widgets/sow-headline-default-86354344b241.css?ver=5.3.1" id="sow-headline-default-86354344b241-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://anshome.org/wp-content/uploads/siteorigin-widgets/sow-image-default-8358abbce072.css?ver=5.3.1" id="sow-image-default-8358abbce072-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://anshome.org/wp-content/uploads/maxmegamenu/style.css?ver=b73be0" id="megamenu-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://anshome.org/wp-includes/css/dashicons.min.css?ver=5.3.1" id="dashicons-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://anshome.org/wp-content/plugins/megamenu-pro/icons/fontawesome/css/font-awesome.min.css?ver=1.5.2" id="megamenu-fontawesome-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://anshome.org/wp-content/plugins/megamenu-pro/icons/genericons/genericons/genericons.css?ver=1.5.2" id="megamenu-genericons-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://anshome.org/wp-content/plugins/search-filter-pro/public/assets/css/search-filter.min.css?ver=2.4.6" id="search-filter-plugin-styles-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://anshome.org/wp-content/themes/twentytwelve/style.css?ver=5.3.1" id="twentytwelve-style-css" media="all" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 9]>
# <link rel='stylesheet' id='twentytwelve-ie-css'  href='https://anshome.org/wp-content/themes/twentytwelve/css/ie.css?ver=20121010' type='text/css' media='all' />
# <![endif]-->
# <link href="https://anshome.org/wp-content/plugins/tabs-widget-for-page-builder/assets/css/style.min.css?ver=1.2.1" id="pt-tabs-style-css" media="all" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# /* <![CDATA[ */
# var monsterinsights_frontend = {"js_events_tracking":"true","is_debug_mode":"false","download_extensions":"doc,exe,js,pdf,ppt,tgz,zip,xls","inbound_paths":"","home_url":"https:\/\/anshome.org","track_download_as":"event","internal_label":"int","hash_tracking":"false"};
# /* ]]> */
# </script>
# <script src="https://anshome.org/wp-content/plugins/google-analytics-for-wordpress/assets/js/frontend.min.js?ver=7.3.2" type="text/javascript"></script>
# <script src="https://anshome.org/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp" type="text/javascript"></script>
# <script src="https://anshome.org/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var SF_LDATA = {"ajax_url":"https:\/\/anshome.org\/wp-admin\/admin-ajax.php","home_url":"https:\/\/anshome.org\/"};
# /* ]]> */
# </script>
# <script src="https://anshome.org/wp-content/plugins/search-filter-pro/public/assets/js/search-filter-build.min.js?ver=2.4.6" type="text/javascript"></script>
# <script src="https://anshome.org/wp-content/plugins/search-filter-pro/public/assets/js/chosen.jquery.min.js?ver=2.4.6" type="text/javascript"></script>
# <script src="https://anshome.org/wp-content/themes/twentytwelve/js/custom.js?ver=5.3.1" type="text/javascript"></script>
# <script src="https://anshome.org/wp-content/plugins/tabs-widget-for-page-builder/assets/js/main.min.js?ver=1.2.1" type="text/javascript"></script>
# <link href="https://anshome.org/wp-json/" rel="https://api.w.org/"/>
# <link href="https://anshome.org/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://anshome.org/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 5.3.1" name="generator"/>
# <link href="https://anshome.org/?p=155" rel="shortlink"/>
# <link href="https://anshome.org/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fanshome.org%2Fevents-calendar%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://anshome.org/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fanshome.org%2Fevents-calendar%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <!-- EventON Version -->
# <meta content="EventON 2.7.3" name="generator"/>
# <style id="twentytwelve-header-css" type="text/css">
# 			.site-title,
# 		.site-description {
# 			position: absolute;
# 			clip: rect(1px 1px 1px 1px); /* IE7 */
# 			clip: rect(1px, 1px, 1px, 1px);
# 		}
# 		</style>
# <style id="siteorigin-panels-layouts-head" media="all" type="text/css">/* Layout 155 */ #pgc-155-0-0 { width:20.0311%;width:calc(20.0311% - ( 0.79968944099379 * 0px ) ) } #pl-155 #panel-155-0-0-0 , #pl-155 #panel-155-0-1-0 , #pl-155 #panel-155-1-0-0 {  } #pgc-155-0-1 { width:79.9689%;width:calc(79.9689% - ( 0.20031055900621 * 0px ) ) } #pg-155-0 , #pl-155 .so-panel:last-child { margin-bottom:0px } #pgc-155-1-0 { width:100%;width:calc(100% - ( 0 * 30px ) ) } #pl-155 .so-panel { margin-bottom:30px } @media (max-width:780px){ #pg-155-0.panel-no-style, #pg-155-0.panel-has-style > .panel-row-style , #pg-155-1.panel-no-style, #pg-155-1.panel-has-style > .panel-row-style { -webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column } #pg-155-0 .panel-grid-cell , #pg-155-1 .panel-grid-cell { margin-right:0 } #pg-155-0 .panel-grid-cell , #pg-155-1 .panel-grid-cell { width:100% } #pgc-155-0-0 { margin-bottom:30px } #pl-155 .panel-grid-cell { padding:0 } #pl-155 .panel-grid .panel-grid-cell-empty { display:none } #pl-155 .panel-grid .panel-grid-cell-mobile-last { margin-bottom:0px }  } </style> <style id="wp-custom-css" type="text/css">
# 			/* Vantage Remove Image Shadow and Rounding */
#
# .entry-content img { -webkit-border-radius: 0 !important; -moz-border-radius: 0 !important; border-radius: 0 !important; -webkit-box-shadow: none !important; -moz-box-shadow: none !important; box-shadow: none !important }
#
# /* Change link color */
# a {color: #25408F;}
#
# /* Visited links */
# a:visited {color: #41AD49;}
#
# /* Hover links */
# a:hover {font-weight: bold;}
# 		</style>
# <style type="text/css">/** Mega Menu CSS: fs **/</style>
# <script type="text/javascript">
# jQuery(window).load(function() {
# // 	jQuery(".loader").fadeOut("slow");
# 	jQuery(".testimonial-image img").each(function() {
# 		var imgW = jQuery(this).width();
# 		var imgH = jQuery(this).height();
# 		if(imgW > imgH){
# 			jQuery(this).parent().parent().width('100%');
# 		} else  {
# 			jQuery(this).parent().parent().width('50%');
# 		}
# 	});
# });
# </script>
# </head>
# <body class="page-template-default page page-id-155 siteorigin-panels siteorigin-panels-before-js mega-menu-max-mega-menu-1 mega-menu-primary mega-menu-max-mega-menu-2 mega-menu-max-mega-menu-3 mega-menu-max-mega-menu-4 mega-menu-max-mega-menu-5 mega-menu-max-mega-menu-6 mega-menu-max-mega-menu-7 mega-menu-max-mega-menu-8 full-width" data-rsssl="1">
# <div class="spinner-wrapper">
# <div class="spinner">
# <div class="bounce1"></div>
# <div class="bounce2"></div>
# <div class="bounce3"></div>
# </div>
# </div>
# <div class="hfeed site" id="page">
# <div class="modal">
# <aside><a class="modal-cls-btn" href="#"><img alt="Close Button" src="https://anshome.org/wp-content/uploads/2019/08/close-button.png"/></a><a href="https://anshome.org/nature-for-all/"><img alt="" class="image wp-image-13290 attachment-full size-full" height="868" sizes="(max-width: 600px) 100vw, 600px" src="https://anshome.org/wp-content/uploads/2019/09/ANS-Thermometer-6-1.jpg" srcset="https://anshome.org/wp-content/uploads/2019/09/ANS-Thermometer-6-1.jpg 600w, https://anshome.org/wp-content/uploads/2019/09/ANS-Thermometer-6-1-207x300.jpg 207w" style="max-width: 100%; height: auto;" width="600"/></a></aside> </div>
# <header class="site-header" id="masthead" role="banner">
# <div class="site-logo">
# <a href="https://anshome.org/" rel="home" title="Audubon Naturalist Society"><img alt="Audubon Naturalist Society" src="https://anshome.org/wp-content/uploads/2016/09/Logo.png"/></a>
# </div>
# <!-- #Header-widgets -->
# <div class="widget-area" id="header-widgets">
# <aside class="widget widget_sow-editor" id="sow-editor-3"><div class="so-widget-sow-editor so-widget-sow-editor-base">
# <div class="siteorigin-widget-tinymce textwidget">
# <a href="https://www.youtube.com/user/audubonnaturalist"><img alt="" class="alignnone wp-image-1970" height="30" src="https://anshome.org/wp-content/uploads/2017/04/1493312015_youtube_online_social_media.png" width="30"/></a> <a href="https://www.facebook.com/AudubonNaturalistSociety"><img alt="" class="alignnone wp-image-1971" height="30" src="https://anshome.org/wp-content/uploads/2017/04/1493312058_online_social_media_facebook.png" width="30"/></a> <a href="https://twitter.com/anstweets"><img alt="" class="alignnone wp-image-1972" height="30" src="https://anshome.org/wp-content/uploads/2017/04/1493312061_twitter_online_social_media.png" width="30"/></a></div>
# </div></aside><aside class="widget widget_search_filter_register_widget" id="search_filter_register_widget-2"><form action="https://anshome.org/results/" autocomplete="off" class="searchandfilter" data-ajax="1" data-ajax-data-type="json" data-ajax-form-url="https://anshome.org/?sfid=13425&amp;sf_action=get_data&amp;sf_data=form" data-ajax-links-selector=".pagination a" data-ajax-pagination-type="normal" data-ajax-target="#search-filter-results-13425" data-ajax-url="https://anshome.org/?sfid=13425&amp;sf_action=get_data&amp;sf_data=results" data-auto-update="1" data-display-result-method="shortcode" data-init-paged="1" data-instance-count="1" data-is-rtl="0" data-lang-code="" data-maintain-state="" data-only-results-ajax="1" data-results-url="https://anshome.org/results/" data-scroll-to-pos="0" data-sf-form-id="13425" data-template-loaded="0" data-update-ajax-url="1" data-use-history-api="1" id="search-filter-form-13425" method="post"><ul><li class="sf-field-search" data-sf-field-input-type="" data-sf-field-name="search" data-sf-field-type="search"> <label><input class="sf-input-text" name="_sf_search[]" placeholder="Search …" title="" type="text" value=""/></label> </li><li class="sf-field-submit" data-sf-field-input-type="" data-sf-field-name="submit" data-sf-field-type="submit"><input name="_sf_submit" type="submit" value="Submit"/></li></ul></form></aside><aside class="widget widget_maxmegamenu" id="maxmegamenu-2"><div class="mega-menu-wrap" id="mega-menu-wrap-max_mega_menu_6"><div class="mega-menu-toggle" tabindex="0"><div class="mega-toggle-blocks-left"></div><div class="mega-toggle-blocks-center"></div><div class="mega-toggle-blocks-right"><div class="mega-toggle-block mega-menu-toggle-block mega-toggle-block-1" id="mega-toggle-block-1"><span class="mega-toggle-label"><span class="mega-toggle-label-closed">MENU</span><span class="mega-toggle-label-open">MENU</span></span></div></div></div><ul class="mega-menu max-mega-menu mega-menu-horizontal mega-no-js" data-breakpoint="500" data-document-click="collapse" data-effect="fade_up" data-effect-mobile="disabled" data-effect-speed="200" data-effect-speed-mobile="200" data-event="hover_intent" data-mobile-force-width="false" data-second-click="close" data-unbind="true" data-vertical-behaviour="accordion" id="mega-menu-max_mega_menu_6"><li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-menu-item-has-children mega-align-bottom-right mega-menu-flyout mega-hide-arrow mega-has-icon mega-menu-item-727" id="mega-menu-item-727"><a aria-haspopup="true" class="mega-custom-icon mega-menu-link" href="#" tabindex="0">MEDIA &amp; RESOURCES<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-menu-item-has-children mega-menu-item-726" id="mega-menu-item-726"><a aria-haspopup="true" class="mega-menu-link" href="#">RESOURCE LIBRARY<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-menu-item-has-children mega-menu-item-909" id="mega-menu-item-909"><a aria-haspopup="true" class="mega-menu-link" href="#">ANS PUBLICATIONS<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-927" id="mega-menu-item-927"><a class="mega-menu-link" href="https://anshome.org/naturalist-quarterly/">NATURALIST QUARTERLY</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-917" id="mega-menu-item-917"><a class="mega-menu-link" href="https://anshome.org/audubon-e-news/">AUDUBON E NEWS</a></li><li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-menu-item-914" id="mega-menu-item-914"><a class="mega-menu-link" href="#">NATURE NOTE'S BLOG</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-911" id="mega-menu-item-911"><a class="mega-menu-link" href="https://anshome.org/voice-of-the-naturalist/">VOICE OF THE NATURALIST</a></li> </ul>
# </li> </ul>
# </li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-5278" id="mega-menu-item-5278"><a class="mega-menu-link" href="https://anshome.org/newsroom/">ANS NEWSROOM</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-2961" id="mega-menu-item-2961"><a class="mega-menu-link" href="https://anshome.org/experts/">ANS EXPERTS</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-3515" id="mega-menu-item-3515"><a class="mega-menu-link" href="https://anshome.org/photo-gallery/">PHOTO GALLERY</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-725" id="mega-menu-item-725"><a class="mega-menu-link" href="https://anshome.org/ans-brand-center/">ANS BRAND CENTER</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-719" id="mega-menu-item-719"><a class="mega-menu-link" href="https://anshome.org/ans-toolkit/">ANS 120 TOOLKIT</a></li></ul>
# </li><li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-align-bottom-left mega-menu-flyout mega-has-icon mega-menu-item-438" id="mega-menu-item-438"><a class="mega-custom-icon mega-menu-link" href="https://anshome.org/2017/04/ans-120-campaign/%20" tabindex="0" target="_blank">ANS 120</a></li></ul></div></aside>
# </div><!-- #Header-widgets -->
# <nav class="main-navigation" id="site-navigation" role="navigation">
# <div class="mega-menu-wrap" id="mega-menu-wrap-primary"><div class="mega-menu-toggle" tabindex="0"><div class="mega-toggle-blocks-left"></div><div class="mega-toggle-blocks-center"></div><div class="mega-toggle-blocks-right"><div class="mega-toggle-block mega-menu-toggle-block mega-toggle-block-1" id="mega-toggle-block-1"><span class="mega-toggle-label"><span class="mega-toggle-label-closed">MENU</span><span class="mega-toggle-label-open">MENU</span></span></div></div></div><ul class="mega-menu max-mega-menu mega-menu-horizontal mega-no-js" data-breakpoint="700" data-document-click="collapse" data-effect="fade_up" data-effect-mobile="disabled" data-effect-speed="200" data-effect-speed-mobile="200" data-event="hover_intent" data-mobile-force-width="false" data-second-click="close" data-unbind="true" data-vertical-behaviour="accordion" id="mega-menu-primary"><li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-menu-item-has-children mega-align-bottom-left mega-menu-flyout mega-menu-item-1076" id="mega-menu-item-1076"><a aria-haspopup="true" class="mega-menu-link" href="https://anshome.org/2017/04/donate/" tabindex="0">DONATE<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-437" id="mega-menu-item-437"><a class="mega-menu-link" href="https://anshome.org/ways-to-give/">WAYS TO GIVE</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-3056" id="mega-menu-item-3056"><a class="mega-menu-link" href="https://anshome.org/membership/">JOIN/RENEW</a></li><li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-menu-item-436" id="mega-menu-item-436"><a class="mega-menu-link" href="https://anshome.org/2017/04/tribute-gifts/%20" target="_blank">TRIBUTE GIFTS</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-5045" id="mega-menu-item-5045"><a class="mega-menu-link" href="https://anshome.org/plant-a-tree/">PLANT A TREE</a></li></ul>
# </li><li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-menu-item-has-children mega-align-bottom-left mega-menu-flyout mega-menu-item-1085" id="mega-menu-item-1085"><a aria-haspopup="true" class="mega-menu-link" href="#" tabindex="0">EDUCATION<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-239" id="mega-menu-item-239"><a class="mega-menu-link" href="https://anshome.org/parents/">PARENTS</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-238" id="mega-menu-item-238"><a class="mega-menu-link" href="https://anshome.org/teachers/">TEACHERS</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-1089" id="mega-menu-item-1089"><a class="mega-menu-link" href="https://anshome.org/ans-preschool/">ANS PRESCHOOL</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-240" id="mega-menu-item-240"><a class="mega-menu-link" href="https://anshome.org/adults/">ADULTS</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-2028" id="mega-menu-item-2028"><a class="mega-menu-link" href="https://anshome.org/summer-camps/">SUMMER CAMPS</a></li></ul>
# </li><li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-menu-item-has-children mega-align-bottom-left mega-menu-flyout mega-menu-item-1353" id="mega-menu-item-1353"><a aria-haspopup="true" class="mega-menu-link" href="#" tabindex="0">CONSERVATION<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-1352" id="mega-menu-item-1352"><a class="mega-menu-link" href="https://anshome.org/conservation/">CONSERVATION</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-1205" id="mega-menu-item-1205"><a class="mega-menu-link" href="https://anshome.org/conservation-events/">CONSERVATION EVENTS</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-12870" id="mega-menu-item-12870"><a class="mega-menu-link" href="https://anshome.org/woodend-restoration/">WOODEND RESTORATION</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-1203" id="mega-menu-item-1203"><a class="mega-menu-link" href="https://anshome.org/policy-and-advocacy/">POLICY AND ADVOCACY</a></li><li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-menu-item-1207" id="mega-menu-item-1207"><a class="mega-menu-link" href="http://conservationblog.anshome.org" target="_blank">CONSERVATION BLOG</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-193" id="mega-menu-item-193"><a class="mega-menu-link" href="https://anshome.org/take-action/">TAKE ACTION</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-12580" id="mega-menu-item-12580"><a class="mega-menu-link" href="https://anshome.org/climate/">CLIMATE ACTIONS</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-1204" id="mega-menu-item-1204"><a class="mega-menu-link" href="https://anshome.org/citizen-science/">COMMUNITY SCIENCE</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-1206" id="mega-menu-item-1206"><a class="mega-menu-link" href="https://anshome.org/training/">TRAINING</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-2278" id="mega-menu-item-2278"><a class="mega-menu-link" href="https://anshome.org/crowder-messersmith-fund/">CROWDER-MESSERSMITH FUND</a></li></ul>
# </li><li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-current-menu-ancestor mega-current-menu-parent mega-menu-item-has-children mega-align-bottom-left mega-menu-flyout mega-menu-item-177" id="mega-menu-item-177"><a aria-haspopup="true" class="mega-menu-link" href="#" tabindex="0">GET INVOLVED<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-11546" id="mega-menu-item-11546"><a class="mega-menu-link" href="https://anshome.org/nature-for-all/">NATURE FOR ALL</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-11552" id="mega-menu-item-11552"><a class="mega-menu-link" href="https://anshome.org/woodend-restoration/">WOODEND RESTORATION</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-current-menu-item mega-page_item mega-page-item-155 mega-current_page_item mega-menu-item-241" id="mega-menu-item-241"><a class="mega-menu-link" href="https://anshome.org/events-calendar/">EVENTS</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-195" id="mega-menu-item-195"><a class="mega-menu-link" href="https://anshome.org/volunteer/">VOLUNTEER</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-2464" id="mega-menu-item-2464"><a class="mega-menu-link" href="https://anshome.org/conferences/">CONFERENCES</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-1154" id="mega-menu-item-1154"><a class="mega-menu-link" href="https://anshome.org/naturalist-shop/">NATURALIST SHOP</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-192" id="mega-menu-item-192"><a class="mega-menu-link" href="https://anshome.org/share-your-story/">SHARE YOUR STORY</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-2519" id="mega-menu-item-2519"><a class="mega-menu-link" href="https://anshome.org/your-ans-stories/">YOUR ANS STORIES</a></li></ul>
# </li><li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-menu-item-has-children mega-align-bottom-left mega-menu-flyout mega-menu-item-1050" id="mega-menu-item-1050"><a aria-haspopup="true" class="mega-menu-link" href="#" tabindex="0">ABOUT<span class="mega-indicator"></span></a>
# <ul class="mega-sub-menu">
# <li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-1051" id="mega-menu-item-1051"><a class="mega-menu-link" href="https://anshome.org/mission/">MISSION</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-1159" id="mega-menu-item-1159"><a class="mega-menu-link" href="https://anshome.org/visit/">VISIT</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-1056" id="mega-menu-item-1056"><a class="mega-menu-link" href="https://anshome.org/annual-reports/">ANNUAL/FINANCIAL REPORTS</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-1052" id="mega-menu-item-1052"><a class="mega-menu-link" href="https://anshome.org/board-of-directors/">BOARD OF DIRECTORS</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-1053" id="mega-menu-item-1053"><a class="mega-menu-link" href="https://anshome.org/staff/">STAFF</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-12871" id="mega-menu-item-12871"><a class="mega-menu-link" href="https://anshome.org/woodend-restoration/">WOODEND RESTORATION</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-1055" id="mega-menu-item-1055"><a class="mega-menu-link" href="https://anshome.org/strategic-plan/">STRATEGIC PLAN</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-menu-item-1054" id="mega-menu-item-1054"><a class="mega-menu-link" href="https://anshome.org/careers/">CAREERS</a></li></ul>
# </li><li class="mega-menu-item mega-menu-item-type-custom mega-menu-item-object-custom mega-align-bottom-left mega-menu-flyout mega-menu-item-1399" id="mega-menu-item-1399"><a class="mega-menu-link" href="http://woodendsanctuary.org" tabindex="0">RENTALS</a></li></ul></div> </nav><!-- #site-navigation -->
# </header><!-- #masthead -->
# <div class="wrapper" id="main">
# <div class="site-content" id="primary">
# <div id="content" role="main">
# <article class="post-155 page type-page status-publish hentry" id="post-155">
# <div class="entry-content">
# <div class="panel-layout" id="pl-155"><div class="panel-grid panel-has-style" id="pg-155-0"><div class="slideContainerInner panel-row-style panel-row-style-for-155-0"><div class="panel-grid-cell" id="pgc-155-0-0"><div class="so-panel widget widget_maxmegamenu panel-first-child panel-last-child" data-index="0" id="panel-155-0-0-0"><h3 class="widget-title">Get Involved</h3><div class="mega-menu-wrap" id="mega-menu-wrap-max_mega_menu_4"><div class="mega-menu-toggle" tabindex="0"><div class="mega-toggle-blocks-left"></div><div class="mega-toggle-blocks-center"></div><div class="mega-toggle-blocks-right"><div class="mega-toggle-block mega-menu-toggle-block mega-toggle-block-1" id="mega-toggle-block-1"><span class="mega-toggle-label"><span class="mega-toggle-label-closed">MENU</span><span class="mega-toggle-label-open">MENU</span></span></div></div></div><ul class="mega-menu max-mega-menu mega-menu-vertical mega-no-js" data-breakpoint="780" data-document-click="collapse" data-effect="fade_up" data-effect-mobile="disabled" data-effect-speed="200" data-effect-speed-mobile="200" data-event="hover_intent" data-mobile-force-width="false" data-second-click="close" data-unbind="true" data-vertical-behaviour="accordion" id="mega-menu-max_mega_menu_4"><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-align-bottom-left mega-menu-flyout mega-menu-item-11544" id="mega-menu-item-11544"><a class="mega-menu-link" href="https://anshome.org/nature-for-all/" tabindex="0">NATURE FOR ALL</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-current-menu-item mega-page_item mega-page-item-155 mega-current_page_item mega-align-bottom-left mega-menu-flyout mega-menu-item-639" id="mega-menu-item-639"><a class="mega-menu-link" href="https://anshome.org/events-calendar/" tabindex="0">EVENTS</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-align-bottom-left mega-menu-flyout mega-menu-item-118" id="mega-menu-item-118"><a class="mega-menu-link" href="https://anshome.org/volunteer/" tabindex="0">VOLUNTEER</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-align-bottom-left mega-menu-flyout mega-menu-item-2482" id="mega-menu-item-2482"><a class="mega-menu-link" href="https://anshome.org/conferences/" tabindex="0">CONFERENCES</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-align-bottom-left mega-menu-flyout mega-menu-item-1155" id="mega-menu-item-1155"><a class="mega-menu-link" href="https://anshome.org/naturalist-shop/" tabindex="0">NATURALIST SHOP</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-align-bottom-left mega-menu-flyout mega-menu-item-117" id="mega-menu-item-117"><a class="mega-menu-link" href="https://anshome.org/share-your-story/" tabindex="0">SHARE YOUR STORY</a></li><li class="mega-menu-item mega-menu-item-type-post_type mega-menu-item-object-page mega-align-bottom-left mega-menu-flyout mega-menu-item-2523" id="mega-menu-item-2523"><a class="mega-menu-link" href="https://anshome.org/your-ans-stories/" tabindex="0">YOUR ANS STORIES</a></li></ul></div></div></div><div class="panel-grid-cell" id="pgc-155-0-1"><div class="so-panel widget widget_sow-image panel-first-child panel-last-child" data-index="1" id="panel-155-0-1-0"><div class="so-widget-sow-image so-widget-sow-image-default-8358abbce072">
# <div class="sow-image-container">
# <img alt="" class="so-widget-image" height="556" sizes="(max-width: 1280px) 100vw, 1280px" src="https://anshome.org/wp-content/uploads/2019/07/ANS-Events.png" srcset="https://anshome.org/wp-content/uploads/2019/07/ANS-Events.png 1280w, https://anshome.org/wp-content/uploads/2019/07/ANS-Events-300x130.png 300w, https://anshome.org/wp-content/uploads/2019/07/ANS-Events-768x334.png 768w, https://anshome.org/wp-content/uploads/2019/07/ANS-Events-1024x445.png 1024w, https://anshome.org/wp-content/uploads/2019/07/ANS-Events-624x271.png 624w" title="Events" width="1280"/>
# </div>
# <h3 class="widget-title">Events</h3></div></div></div></div></div><div class="panel-grid panel-has-style" id="pg-155-1"><div class="innerContent panel-row-style panel-row-style-for-155-1"><div class="panel-grid-cell" id="pgc-155-1-0"><div class="so-panel widget widget_evcalwidget_sc EvcalWidget_SC panel-first-child panel-last-child" data-index="2" id="panel-155-1-0-0"><h3 class="widget-title"> </h3><div class="evo_widget" id="evcal_widget"><div class="ajde_evcal_calendar" id="evcal_calendar_765"><div class="evo-data" data-accord="0" data-cal_ver="2.7.3" data-cmonth="12" data-cyear="2019" data-ev_cnt="0" data-evc_open="0" data-filters_on="true" data-mapformat="roadmap" data-mapiconurl="" data-mapscroll="true" data-mapzoom="18" data-range_end="0" data-range_start="0" data-rtl="no" data-runajax="1" data-send_unix="0" data-show_limit="no" data-sort_by="sort_date" data-tiles="no" data-ux_val="1"></div><div class="calendar_header evcal_nosort" id="evcal_head"><div class="evo_cal_above"><span class="evo-jumper-btn">Jump Months</span><span class="evo-gototoday-btn" data-dy="" data-mo="12" data-yr="2019" style="display:none">Current Month</span></div><div class="evo_cal_above_content"><div class="evo_j_container" data-expj="yes" data-m="12" data-y="2019" style="display:block">
# <div class="evo_j_months evo_j_dates" data-val="m">
# <div class="legend evo_jumper_months"><a data-val="1" title="january">january</a><a data-val="2" title="february">february</a><a data-val="3" title="march">march</a><a data-val="4" title="april">april</a><a data-val="5" title="may">may</a><a data-val="6" title="june">june</a><a data-val="7" title="july">july</a><a data-val="8" title="august">august</a><a data-val="9" title="september">september</a><a data-val="10" title="october">october</a><a data-val="11" title="november">november</a><a class="current set" data-val="12" title="december">december</a></div><div class="clear"></div></div>
# <div class="evo_j_years evo_j_dates" data-val="y">
# <p class="legend"><a class="current set" data-val="2019">2019</a><a data-val="2020">2020</a></p><div class="clear"></div>
# </div>
# </div></div><p class="evo_month_title" id="evcal_cur"> december, 2019</p><div class="cal_arguments" data-etc_override="yes" data-evc_open="no" data-event_order="ASC" data-eventtop_style="0" data-ft_event_priority="no" data-hide_end_time="no" data-hide_ft="no" data-hide_mult_occur="no" data-hide_past="no" data-lang="L1" data-members_only="no" data-month_incre="0" data-only_ft="no" data-s="" data-show_et_ft_img="no" data-show_limit="no" data-show_limit_ajax="no" data-show_limit_paged="1" data-show_limit_redir="0" data-show_repeats="no" data-tile_bg="0" data-tile_count="2" data-tile_height="0" data-tile_style="0" data-tiles="no" data-ux_val="1" style="display:none"></div><div class="clear"></div></div><div class="eventon_sorting_section" style="display:none"><div class="eventon_filter_line"><div class="eventon_filter" data-filter_field="event_type" data-filter_type="tax" data-filter_val="39" data-fl_o="IN"></div><div class="eventon_filter" data-filter_field="event_type_2" data-filter_type="tax" data-filter_val="all" data-fl_o="IN"></div><div class="eventon_filter" data-filter_field="event_type_3" data-filter_type="tax" data-filter_val="all" data-fl_o="IN"></div><div class="eventon_filter" data-filter_field="event_type_4" data-filter_type="tax" data-filter_val="all" data-fl_o="IN"></div><div class="eventon_filter" data-filter_field="event_type_5" data-filter_type="tax" data-filter_val="all" data-fl_o="IN"></div><div class="eventon_filter" data-filter_field="event_location" data-filter_type="tax" data-filter_val="all" data-fl_o="IN"></div><div class="eventon_filter" data-filter_field="event_organizer" data-filter_type="tax" data-filter_val="all" data-fl_o="IN"></div><div class="eventon_filter" data-filter_field="event_tag" data-filter_type="tax" data-filter_val="all" data-fl_o="IN"></div></div><div class="clear"></div></div><div id="eventon_loadbar_section"><div id="eventon_loadbar"></div></div><div class="eventon_events_list" id="evcal_list"><div class="eventon_list_event evo_eventtop past_event event event_3452_0" data-colr="#" data-event_id="3452" data-ri="0r" data-time="1575635400-1575639000" id="event_3452" itemscope="" itemtype="http://schema.org/Event"><div class="evo_event_schema" style="display:none"><a href="https://anshome.org/events/preschool-open-house/" itemprop="url"></a><span itemprop="name">Preschool Open House</span><meta itemprop="image"/><meta content="Audubon Nature Preschool Open House  The Admissions Open House at Audubon Nature Preschool is a fun opportunity for families to explore our indoor and outdoor classrooms and learn about our class" itemprop="description"/><meta content="2019-12-6T12:30" itemprop="startDate"/><meta content="2019-12-6T13:30" itemprop="endDate"/><meta content="on-schedule" itemprop="eventStatus"/>
# <item itemprop="location" itemscope="" itemtype="http://schema.org/Place" style="display:none">
# <span itemprop="name">Woodend Nature Sanctuary</span>
# <span itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <item itemprop="streetAddress">8940 Jones Mill Road, Chevy Chase, MD 20815, USA</item>
# </span></item><script type="application/ld+json">{	"@context": "http://schema.org",
# 							  	"@type": "Event",
# 							  	"name": "Preschool Open House",
# 							  	"startDate": "2019-12-6T12-12-30-00",
# 							  	"endDate": "2019-12-6T13-13-30-00",
# 							  	"image":"https://anshome.org/events/preschool-open-house/",
# 							  	"description":"Audubon Nature Preschool Open House  The Admissions Open House at Audubon Nature Preschool is a fun opportunity for families to explore our indoor and outdoor classrooms and learn about our class"
# 							  	,"location":{
# 										"@type":"Place",
# 										"name":"Woodend Nature Sanctuary",
# 										"address":{
# 											"@type": "PostalAddress"
# 											"streetAddress":"8940 Jones Mill Road, Chevy Chase, MD 20815, USA"
# 										}
# 							  		}
# 							 }</script></div>
# <p class="desc_trig_outter"><a class="desc_trig sin_val evcal_list_a" data-exlk="0" data-gmap_status="null" data-gmtrig="1" data-ux_val="1" id="evc_15756354003452" style="border-color: #;"><span class="evcal_cblock" data-bgcolor="#" data-smon="december" data-syr="2019"><span class="evo_start"><em class="date">06</em><em class="month">dec</em><em class="time">12:30 pm</em></span><span class="evo_end only_time"><em class="time">1:30 pm</em></span><em class="clear"></em></span><span class="evcal_desc evo_info hide_eventtopdata" data-latlng="39.003311,-77.067332" data-location_address="8940 Jones Mill Road, Chevy Chase, MD 20815, USA" data-location_name="Woodend Nature Sanctuary" data-location_status="true" data-location_type="lonlat" data-location_url="https://anshome.org/event-location/woodend-nature-sanctuary/"><span class="evo_above_title"></span><span class="evcal_desc2 evcal_event_title" itemprop="name">Preschool Open House</span><span class="evo_below_title"></span><span class="evcal_desc_info"></span><span class="evcal_desc3"></span></span><em class="clear"></em></a></p><div class="event_description evcal_eventcard" style="display:none"><div class="evo_metarow_details evorow evcal_evdata_row bordb evcal_event_details">
# <div class="event_excerpt" style="display:none"><h3 class="padb5 evo_h3">Event Details</h3><p>Audubon Nature Preschool Open House
# The Admissions Open House at Audubon Nature Preschool is a fun opportunity for families to explore our indoor and outdoor classrooms and learn about our class</p></div><span class="evcal_evdata_icons"><i class="fa fa-align-justify"></i></span>
# <div class="evcal_evdata_cell"><div class="eventon_full_description">
# <h3 class="padb5 evo_h3"><span class="evcal_evdata_icons"><i class="fa fa-align-justify"></i></span>Event Details</h3><div class="eventon_desc_in" itemprop="description">
# <h2>Audubon Nature Preschool Open House</h2>
# <p>The Admissions Open House at Audubon Nature Preschool is a fun opportunity for families to explore our indoor and outdoor classrooms and learn about our class offerings. Children are welcome, and families are encouraged to dress for outdoor exploration! <a href="https://anshome.org/preschool-open-house/">RSVP here</a>.</p>
# </div><div class="clear"></div>
# </div>
# </div>
# </div><div class="evo_metarow_time_location evorow bordb">
# <div class="tb">
# <div class="tbrow">
# <div class="evcal_col50 bordr">
# <div class="evcal_evdata_row evo_time">
# <span class="evcal_evdata_icons"><i class="fa fa-clock-o"></i></span>
# <div class="evcal_evdata_cell">
# <h3 class="evo_h3"><span class="evcal_evdata_icons"><i class="fa fa-clock-o"></i></span>Time</h3>
# <p>(Friday) 12:30 pm - 1:30 pm <em class="evo_eventcard_tiemzone">EST</em></p>
# </div>
# </div>
# </div><div class="evcal_col50">
# <div class="evcal_evdata_row evo_location">
# <span class="evcal_evdata_icons"><i class="fa fa-map-marker"></i></span>
# <div class="evcal_evdata_cell" data-loc_tax_id="21">
# <h3 class="evo_h3"><span class="evcal_evdata_icons"><i class="fa fa-map-marker"></i></span>Location</h3><p class="evo_location_name">Woodend Nature Sanctuary</p><p class="evo_location_address">8940 Jones Mill Road, Chevy Chase, MD 20815, USA</p>
# </div>
# </div>
# </div><div class="clear"></div>
# </div></div>
# </div> <div class="evo_metarow_ICS evorow bordb evcal_evdata_row">
# <span class="evcal_evdata_icons"><i class="fa fa-calendar"></i></span>
# <div class="evcal_evdata_cell">
# <p><a class="evo_ics_nCal" href="https://anshome.org/wp-admin/admin-ajax.php?action=eventon_ics_download&amp;event_id=3452&amp;ri=0" title="Add to your calendar">Calendar</a><a class="evo_ics_gCal" href="//www.google.com/calendar/event?action=TEMPLATE&amp;text=Preschool+Open+House&amp;dates=20191206T123000Z/20191206T133000Z&amp;details=Audubon+Nature+Preschool+Open+House%0D%0AThe+Admissions+Open+House+at+Audubon+Nature+Preschool+is+a+fun+opportunity+for+families+to+explore+our+indoor+and+outdoor+classrooms+and+learn+about+our+class&amp;location=Woodend+Nature+Sanctuary - 8940+Jones+Mill+Road%2C+Chevy+Chase%2C+MD+20815%2C+USA" target="_blank" title="Add to google calendar">GoogleCal</a></p>
# </div>
# </div>
# <div class="evo_card_row_end evcal_close" title="Close"></div></div><div class="clear end"></div></div><div class="eventon_list_event evo_eventtop past_event event event_1255_24" data-colr="#" data-event_id="1255" data-ri="24r" data-time="1575709200-1575712800" id="event_1255" itemscope="" itemtype="http://schema.org/Event"><div class="evo_event_schema" style="display:none"><a href="https://anshome.org/events/weekend-walk-in-the-woods/var/ri-24.l-L1" itemprop="url"></a><span itemprop="name">Weekend Walk in the Woods</span><meta itemprop="image"/><meta content="First Saturday of each month, 9-10 am: Each month, an ANS Master Naturalist covers a different topic, such as deer, fungi, trees, insects, and birds. Bring the whole family—all ages" itemprop="description"/><meta content="2019-12-7T09:00" itemprop="startDate"/><meta content="2019-12-7T10:00" itemprop="endDate"/><meta content="on-schedule" itemprop="eventStatus"/>
# <item itemprop="location" itemscope="" itemtype="http://schema.org/Place" style="display:none">
# <span itemprop="name">Woodend Nature Sanctuary</span>
# <span itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <item itemprop="streetAddress">8940 Jones Mill Road, Chevy Chase, MD 20815, USA</item>
# </span></item><script type="application/ld+json">{	"@context": "http://schema.org",
# 							  	"@type": "Event",
# 							  	"name": "Weekend Walk in the Woods",
# ...
# <div class="evcal_evdata_cell"><div class="eventon_full_description">
# <h3 class="padb5 evo_h3"><span class="evcal_evdata_icons"><i class="fa fa-align-justify"></i></span>Event Details</h3><div class="eventon_desc_in" itemprop="description">
# <p>Audubon Nature Preschool’s Wonder and Wander community event features a gently used children’s book sale, a bake sale, and lots of fun exploring the Woodend Nature Sanctuary with teachers and new and old friends. ANP teachers will lead story hikes throughout the morning.</p>
# <p>This is a ticketed event; proceeds help to fund our school. Tickets are $10 per family. RSVP <a href="https://anshome.org/preschool-wonder-wander/">here</a>.</p>
# </div><div class="clear"></div>
# </div>
# </div>
# </div><div class="evo_metarow_time_location evorow bordb">
# <div class="tb">
# <div class="tbrow">
# <div class="evcal_col50 bordr">
# <div class="evcal_evdata_row evo_time">
# <span class="evcal_evdata_icons"><i class="fa fa-clock-o"></i></span>
# <div class="evcal_evdata_cell">
# <h3 class="evo_h3"><span class="evcal_evdata_icons"><i class="fa fa-clock-o"></i></span>Time</h3>
# <p>(Saturday) 10:00 am - 12:00 pm <em class="evo_eventcard_tiemzone">EST</em></p>
# </div>
# </div>
# </div><div class="evcal_col50">
# <div class="evcal_evdata_row evo_location">
# <span class="evcal_evdata_icons"><i class="fa fa-map-marker"></i></span>
# <div class="evcal_evdata_cell" data-loc_tax_id="21">
# <h3 class="evo_h3"><span class="evcal_evdata_icons"><i class="fa fa-map-marker"></i></span>Location</h3><p class="evo_location_name">Woodend Nature Sanctuary</p><p class="evo_location_address">8940 Jones Mill Road, Chevy Chase, MD 20815, USA</p>
# </div>
# </div>
# </div><div class="clear"></div>
# </div></div>
# </div> <div class="evo_metarow_ICS evorow bordb evcal_evdata_row">
# <span class="evcal_evdata_icons"><i class="fa fa-calendar"></i></span>
# <div class="evcal_evdata_cell">
# <p><a class="evo_ics_nCal" href="https://anshome.org/wp-admin/admin-ajax.php?action=eventon_ics_download&amp;event_id=9105&amp;ri=0" title="Add to your calendar">Calendar</a><a class="evo_ics_gCal" href="//www.google.com/calendar/event?action=TEMPLATE&amp;text=Preschool+Community+Event+-+Wonder+%26+Wander&amp;dates=20191207T100000Z/20191207T120000Z&amp;details=Audubon+Nature+Preschool%27s+Wonder+and+Wander+community+event+features+a+gently+used+children%E2%80%99s+book+sale%2C+a+bake+sale%2C+and+lots+of+fun+exploring+the+Woodend+Nature+Sanctuary+with+teachers+and&amp;location=Woodend+Nature+Sanctuary - 8940+Jones+Mill+Road%2C+Chevy+Chase%2C+MD+20815%2C+USA" target="_blank" title="Add to google calendar">GoogleCal</a></p>
# </div>
# </div>
# <div class="evo_card_row_end evcal_close" title="Close"></div></div><div class="clear end"></div></div> <div class="clear"></div>
# </div><!-- #evcal_list-->
# <div class="clear"></div>
# </div><!-- .ajde_evcal_calendar-->
# </div></div></div></div></div></div> </div><!-- .entry-content -->
# <footer class="entry-meta">
# </footer><!-- .entry-meta -->
# </article><!-- #post -->
# </div><!-- #content -->
# </div><!-- #primary -->
# </div><!-- #main .wrapper -->
# <footer id="colophon" role="contentinfo">
# <div class="widget-area three" id="footer-widgets">
# <aside class="widget widget_siteorigin-panels-builder" id="siteorigin-panels-builder-2"><div class="panel-layout" id="pl-w5ce8114c81ebd"><div class="panel-grid panel-has-style" id="pg-w5ce8114c81ebd-0"><div class="siteorigin-panels-stretch panel-row-style panel-row-style-for-w5ce8114c81ebd-0" data-stretch-type="full"><div class="panel-grid-cell" id="pgc-w5ce8114c81ebd-0-0"><div class="so-panel widget widget_sow-headline panel-first-child" data-index="0" id="panel-w5ce8114c81ebd-0-0-0"><div class="panel-widget-style panel-widget-style-for-w5ce8114c81ebd-0-0-0"><div class="so-widget-sow-headline so-widget-sow-headline-default-c731fa1b2d28"><div class="sow-headline-container">
# <h1 class="sow-headline">LET'S KEEP IN TOUCH</h1><h3 class="sow-sub-headline">Stay connected for ANS news and nature for all!</h3></div></div></div></div><div class="so-panel widget widget_sow-button panel-last-child" data-index="1" id="panel-w5ce8114c81ebd-0-0-1"><div class="so-widget-sow-button so-widget-sow-button-atom-4e016696abae"><div class="ow-button-base ow-button-align-center">
# <a class="ow-icon-placement-left ow-button-hover" href="https://anshome.org/lets-keep-in-touch/">
# <span>
#
# 			Sign Up Here		</span>
# </a>
# </div>
# </div></div></div></div></div><div class="panel-grid panel-has-style" id="pg-w5ce8114c81ebd-1"><div class="footerBlock siteorigin-panels-stretch panel-row-style panel-row-style-for-w5ce8114c81ebd-1" data-stretch-type="full"><div class="panel-grid-cell" id="pgc-w5ce8114c81ebd-1-0"><div class="so-panel widget widget_sow-editor panel-first-child panel-last-child" data-index="2" id="panel-w5ce8114c81ebd-1-0-0"><div class="panel-widget-style panel-widget-style-for-w5ce8114c81ebd-1-0-0"><div class="so-widget-sow-editor so-widget-sow-editor-base"><h3 class="widget-title">SITE MAP</h3>
# <div class="siteorigin-widget-tinymce textwidget">
# <p><a href="https://anshome.org/">Home</a><br/>
# <a href="https://anshome.org/2017/04/donate">Donate</a><br/>
# <a href="https://anshome.org/adults/">Education</a><br/>
# <a href="https://anshome.org/conservation-events/">Conservation</a><br/>
# <a href="https://anshome.org/events-calender/">Get Involved</a><br/>
# <a href="https://anshome.org/mission/">About</a><br/>
# <a href="https://anshome.org/careers/">Careers</a><br/>
# <a href="https://anshome.org/naturalist-shop/">Shop</a><br/>
# <a href="http://woodendsanctuary.org">Woodend Rentals</a></p>
# </div>
# </div></div></div></div><div class="panel-grid-cell" id="pgc-w5ce8114c81ebd-1-1"><div class="so-panel widget widget_sow-editor panel-first-child panel-last-child" data-index="3" id="panel-w5ce8114c81ebd-1-1-0"><div class="panel-widget-style panel-widget-style-for-w5ce8114c81ebd-1-1-0"><div class="so-widget-sow-editor so-widget-sow-editor-base"><h3 class="widget-title">CONTACT</h3>
# <div class="siteorigin-widget-tinymce textwidget">
# <p>Woodend Sanctuary - Headquarters<br/>
# 8940 Jones Mill Road<br/>
# Chevy Chase, MD 20815<br/>
# Phone (301) 652-9188<br/>
# <a href="mailto:contact@anshome.org">contact@anshome.org</a><br/>
# <em>Grounds/trails are open dawn to dusk, 7 days a week.</em><br/>
# The mansion is open:<br/>
# <em>Monday-Friday from 9 am-5 pm.</em><br/>
# The Audubon Naturalist Shop is open:<br/>
# <em>Monday-Friday 10 am-5 pm; Saturday 9 am-5 pm; Sunday 12 pm-5 pm.</em></p>
# <p>Rust Nature Sanctuary<br/>
# 802 Children’s Center Road<br/>
# Leesburg, VA 20175<br/>
# Phone (703) 669-0000</p>
# <p><a href="https://anshome.org/ans-speaker/" rel="noopener" target="_blank">Request an ANS Speaker</a></p>
# <p><a href="https://anshome.org/ans-exhibitor/" rel="noopener" target="_blank">Request an ANS Event Exhibitor</a></p>
# <p><a href="https://www.facebook.com/AudubonNaturalistSociety"><img alt="" class="alignnone size-full wp-image-1265" height="27" src="https://anshome.org/wp-content/uploads/2017/03/facebook-256.png" width="27"/></a>   <a href="https://www.youtube.com/user/audubonnaturalist"><img alt="" class="alignnone size-full wp-image-1267" height="27" src="https://anshome.org/wp-content/uploads/2017/03/youtube-xxl.png" width="27"/></a>   <a href="https://twitter.com/anstweets"><img alt="" class="alignnone wp-image-1266 size-full" height="27" src="https://anshome.org/wp-content/uploads/2017/03/twitter-512-e1490981558317.gif" width="27"/></a></p>
# </div>
# </div></div></div></div></div></div><div class="panel-grid panel-has-style" id="pg-w5ce8114c81ebd-2"><div class="siteorigin-panels-stretch panel-row-style panel-row-style-for-w5ce8114c81ebd-2" data-stretch-type="full"><div class="panel-grid-cell" id="pgc-w5ce8114c81ebd-2-0"><div class="so-panel widget widget_sow-editor panel-first-child panel-last-child" data-index="4" id="panel-w5ce8114c81ebd-2-0-0"><div class="so-widget-sow-editor so-widget-sow-editor-base">
# <div class="siteorigin-widget-tinymce textwidget">
# <p><a href="https://anshome.org/">HOME</a>  |  <a href="https://anshome.org/privacy-policy/">PRIVACY POLICY</a></p>
# </div>
# </div></div></div></div></div></div></aside> </div><!-- #footer-widgets -->
# </footer><!-- #colophon -->
# </div><!-- #page -->
# <script alt="evo_map_styles" type="text/javascript">
# 		/*<![CDATA[*/
# 		var gmapstyles = 'default';
# 		/* ]]> */
# 		</script>
# <style id="siteorigin-panels-layouts-footer" media="all" type="text/css">/* Layout w5ce8114c81ebd */ #pgc-w5ce8114c81ebd-0-0 , #pgc-w5ce8114c81ebd-2-0 { width:100%;width:calc(100% - ( 0 * 0px ) ) } #pl-w5ce8114c81ebd #panel-w5ce8114c81ebd-0-0-0 , #pl-w5ce8114c81ebd #panel-w5ce8114c81ebd-0-0-1 , #pl-w5ce8114c81ebd #panel-w5ce8114c81ebd-1-0-0 , #pl-w5ce8114c81ebd #panel-w5ce8114c81ebd-1-1-0 , #pl-w5ce8114c81ebd #panel-w5ce8114c81ebd-2-0-0 {  } #pg-w5ce8114c81ebd-0 , #pg-w5ce8114c81ebd-1 , #pg-w5ce8114c81ebd-2 , #pl-w5ce8114c81ebd .so-panel:last-child { margin-bottom:0px } #pgc-w5ce8114c81ebd-1-0 , #pgc-w5ce8114c81ebd-1-1 { width:50%;width:calc(50% - ( 0.5 * 0px ) ) } #pl-w5ce8114c81ebd .so-panel { margin-bottom:30px } #pg-w5ce8114c81ebd-0> .panel-row-style { background-color:#25afc1;padding:3% 3% 3% 3% } #panel-w5ce8114c81ebd-0-0-0> .panel-widget-style { background-color:#25afc1;padding:5px 0px 5px 0px } #pg-w5ce8114c81ebd-1> .panel-row-style { background-color:#a6a8ab;padding:3% 3% 3% 3% } #panel-w5ce8114c81ebd-1-0-0> .panel-widget-style , #panel-w5ce8114c81ebd-1-0-0 a , #panel-w5ce8114c81ebd-1-1-0> .panel-widget-style , #panel-w5ce8114c81ebd-1-1-0 a { color:#ffffff } #pg-w5ce8114c81ebd-2> .panel-row-style { padding:2% 3% 2% 3% } @media (max-width:780px){ #pg-w5ce8114c81ebd-0.panel-no-style, #pg-w5ce8114c81ebd-0.panel-has-style > .panel-row-style , #pg-w5ce8114c81ebd-1.panel-no-style, #pg-w5ce8114c81ebd-1.panel-has-style > .panel-row-style , #pg-w5ce8114c81ebd-2.panel-no-style, #pg-w5ce8114c81ebd-2.panel-has-style > .panel-row-style { -webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column } #pg-w5ce8114c81ebd-0 .panel-grid-cell , #pg-w5ce8114c81ebd-1 .panel-grid-cell , #pg-w5ce8114c81ebd-2 .panel-grid-cell { margin-right:0 } #pg-w5ce8114c81ebd-0 .panel-grid-cell , #pg-w5ce8114c81ebd-1 .panel-grid-cell , #pg-w5ce8114c81ebd-2 .panel-grid-cell { width:100% } #pgc-w5ce8114c81ebd-1-0 { margin-bottom:30px } #pl-w5ce8114c81ebd .panel-grid-cell { padding:0 } #pl-w5ce8114c81ebd .panel-grid .panel-grid-cell-empty { display:none } #pl-w5ce8114c81ebd .panel-grid .panel-grid-cell-mobile-last { margin-bottom:0px }  } </style><div class="evo_lightboxes" style="display:none"> <div class="evo_lightbox eventcard eventon_events_list" id="">
# <div class="evo_content_in">
# <div class="evo_content_inin">
# <div class="evo_lightbox_content">
# <a class="evolbclose">X</a>
# <div class="evo_lightbox_body eventon_list_event evo_pop_body evcal_eventcard"> </div>
# </div>
# </div>
# </div>
# </div>
# </div><link href="//fonts.googleapis.com/css?family=Oswald%3A400%2C300%7COpen+Sans%3A700%2C400%2C400i%7CRoboto%3A700%2C400&amp;ver=5.3.1" id="evcal_google_fonts-css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//anshome.org/wp-content/plugins/eventON/assets/css/eventon_styles.css?ver=2.7.3" id="evcal_cal_default-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//anshome.org/wp-content/plugins/eventON/assets/fonts/font-awesome.css?ver=2.7.3" id="evo_font_icons-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//anshome.org/wp-content/plugins/eventON/assets/css/eventon_dynamic_styles.css?ver=2.7.3" id="eventon_dynamic_styles-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://anshome.org/wp-content/uploads/siteorigin-widgets/sow-headline-default-c731fa1b2d28.css?ver=5.3.1" id="sow-headline-default-c731fa1b2d28-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://anshome.org/wp-content/uploads/siteorigin-widgets/sow-button-atom-4e016696abae.css?ver=5.3.1" id="sow-button-atom-4e016696abae-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://anshome.org/wp-content/plugins/so-widgets-bundle/widgets/button/css/style.css?ver=1.13.4" id="sow-button-base-css" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://anshome.org/wp-includes/js/jquery/ui/core.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="https://anshome.org/wp-includes/js/jquery/ui/widget.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="https://anshome.org/wp-includes/js/jquery/ui/accordion.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="https://anshome.org/wp-includes/js/jquery/ui/tabs.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="https://anshome.org/wp-includes/js/jquery/ui/effect.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="https://anshome.org/wp-includes/js/jquery/ui/datepicker.min.js?ver=1.11.4" type="text/javascript"></script>
# <script type="text/javascript">
# jQuery(document).ready(function(jQuery){jQuery.datepicker.setDefaults({"closeText":"Close","currentText":"Today","monthNames":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesShort":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"nextText":"Next","prevText":"Previous","dayNames":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"dayNamesShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"dayNamesMin":["S","M","T","W","T","F","S"],"dateFormat":"MM d, yy","firstDay":1,"isRTL":false});});
# </script>
# <script src="https://anshome.org/wp-content/themes/twentytwelve/js/navigation.js?ver=20140711" type="text/javascript"></script>
# <script src="https://anshome.org/wp-content/plugins/page-links-to/js/new-tab.min.js?ver=3.0.0-beta.1" type="text/javascript"></script>
# <script src="https://anshome.org/wp-includes/js/hoverIntent.min.js?ver=1.8.1" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var megamenu = {"timeout":"300","interval":"100"};
# /* ]]> */
# </script>
# <script src="https://anshome.org/wp-content/plugins/megamenu/js/maxmegamenu.js?ver=2.5.2" type="text/javascript"></script>
# <script src="https://anshome.org/wp-content/plugins/megamenu-pro/assets/public.js?ver=1.5.2" type="text/javascript"></script>
# <script src="https://anshome.org/wp-includes/js/wp-embed.min.js?ver=5.3.1" type="text/javascript"></script>
# <script src="//anshome.org/wp-content/plugins/eventON/assets/js/eventon_functions.js?ver=2.7.3" type="text/javascript"></script>
# <script src="https://anshome.org/wp-content/plugins/eventON/assets/js/handlebars.js?ver=2.7.3" type="text/javascript"></script>
# <script src="//anshome.org/wp-content/plugins/eventON/assets/js/jquery.mobile.min.js?ver=2.7.3" type="text/javascript"></script>
# <script src="//anshome.org/wp-content/plugins/eventON/assets/js/jquery.mousewheel.min.js?ver=2.7.3" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var the_ajax_script = {"ajaxurl":"https:\/\/anshome.org\/wp-admin\/admin-ajax.php","postnonce":"390d8b7591"};
# /* ]]> */
# </script>
# <script src="//anshome.org/wp-content/plugins/eventON/assets/js/eventon_script.js?ver=2.7.3" type="text/javascript"></script>
# <script src="//anshome.org/wp-content/plugins/eventON/assets/js/maps/eventon_init_gmap_blank.js?ver=2.7.3" type="text/javascript"></script>
# <script src="//anshome.org/wp-content/plugins/eventON/assets/js/maps/eventon_gen_maps_none.js?ver=2.7.3" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var panelsStyles = {"fullContainer":"body"};
# /* ]]> */
# </script>
# <script src="https://anshome.org/wp-content/plugins/siteorigin-panels/js/styling-295.min.js?ver=2.9.5" type="text/javascript"></script>
# <script type="text/javascript">document.body.className = document.body.className.replace("siteorigin-panels-before-js","");</script></body>
# </html>

# %%
print(soup)
# Out:
# <function soupify_event_page at 0x000002673BBCE840>

# %%
scripts = soup.find_all('script', {'type':'application/ld+json'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-d9eb85f4c591> in <module>
# ----> 1 scripts = soup.find_all('script', {'type':'application/ld+json'})
#
# AttributeError: 'function' object has no attribute 'find_all'
